# %%
import nltk
import re

# %%
question = open('question_1.txt','r').readlines()
answer = open('answer_1.txt','r').readlines()

# %%
for idx,i in enumerate(question):
    question[idx]=i.replace('\n','')

for idx,i in enumerate(answer):
    answer[idx]=i.replace('\n','')

# %%
words_q = []
words_a = []
for i in question:
    words_q.extend(nltk.word_tokenize(i))
for i in answer:
    words_a.extend(nltk.word_tokenize(i))

# %%
len(words)
# Out:
# 5242569

# %%
word2count = {}
for qs in words_q:
    if qs not in word2count:
        word2count[qs] = 1
    else:
        word2count[qs] += 1
        
word2count_a = {}
for qs in words_a:
    if qs not in word2count:
        word2count[qs] = 1
    else:
        word2count[qs] += 1

# %%
len(word2count)
# Out:
# 55567

# %% [markdown]
# ### Remove yang di bawah count 20 (kurang banyak dipakai)

# %%
threshold=30
questionswords2int = {}
word_number = 0
for word, count in word2count.items():
    if count >= threshold:
        questionswords2int[word] = word_number
        word_number += 1
answerswords2int = {}
word_number = 0
for word, count in word2count.items():
    if count >= threshold:
        answerswords2int[word] = word_number
        word_number += 1

# %%
len(questionswords2int),len(answerswords2int)
# Out:
# (10029, 10029)

# %% [markdown]
# ### Masukkan 4 token utama
#
# - PAD : padding
# - EOS : end of sentence
# - OUT : yang tidak ditemukan
# - SOS : end of sentence apa ya?

# %%
tokens = ['<PAD>','<EOS>','<OUT>','<SOS>']
for token in tokens:
    questionswords2int[token] = len(questionswords2int) + 1
for token in tokens:
    answerswords2int[token] = len(answerswords2int) + 1

# %%
questionint2word = dict(zip(questionswords2int.values(),questionswords2int.keys()))
answerint2word = dict(zip(answerswords2int.values(),answerswords2int.keys()))

# %%
len(questionint2word)
# Out:
# 10033

# %%
questionint2word[10032],answerint2word[10032]
# Out:
# ('<OUT>', '<OUT>')

# %%
questionswords2int['salam'], answerswords2int['salam']
# Out:
# (4, 4)

# %% [markdown]
# ### Tambahkan EOS

# %%
for idx, ls in enumerate(question):
    question[idx] = ls + " <EOS>"
for idx, ls in enumerate(answer):
    answer[idx] = ls + " <EOS>"

# %%
question
# Out:
# ['everyagent aka orang noob yang pro <EOS>',
#  'salam dari anak tkj smkn  jakarta <EOS>',
#  'wa  or pm me <EOS>',
#  'aku menyerah dalam bertarung <EOS>',
#  'biarlah ada akhir <EOS>',
#  'sebuah privasi <EOS>',
#  'sudut tersembunyi untukku <EOS>',
#  'aku ingin dilupakan bahkan oleh tuhan <EOS>',
#  'paracelsus <EOS>',
#  'bakar hidrogen facelvega <EOS>',
#  'inspirasi facelvega <EOS>',
#  'kau beruntung semalam <EOS>',
#  'tentu saja kau sendiri <EOS>',
#  'aku adalah jendela terbuka <EOS>',
#  'melebihi tak terhingga <EOS>',
#  'dunia baru di pergelangan tanganmu <EOS>',
#  'tidak diketahui  kesalahan <EOS>',
#  'tahun wakil petugas <EOS>',
#  'tahun detektif kelas satu <EOS>',
#  'ini soal putraku <EOS>',
#  'tahun pialang asuransi <EOS>',
#  'dia belum balas panggilanku <EOS>',
#  'ini bukan sifatnya <EOS>',
#  'kau tahu yang terjadi <EOS>',
#  'terdeteksi di ether satu jam yang lalu <EOS>',
#  'yakin mau lihat <EOS>',
#  'ya <EOS>',
#  'aku mau melihatnya <EOS>',
#  'ether <EOS>',
#  'memasuki lokasi rahasia <EOS>',
#  'informasi rahasia <EOS>',
#  'akses diterima <EOS>',
#  'berhatihatilah <EOS>',
#  'mundur <EOS>',
#  'berkas selesai <EOS>',
#  'aku tahu tempat aku meninggalkannya <EOS>',
#  'kau bisa lihat rekamanku <EOS>',
#  'tahun sosialita <EOS>',
#  'kutinggalkan di kamar mandi hotel <EOS>',
#  'tunjukkan tukang pembersihnya <EOS>',
#  'aku tak dapat bantu <EOS>',
#  'benda itu tak jalan dengan sendirinya <EOS>',
#  'kuharap aku bisa bantu <EOS>',
#  'kita pergi <EOS>',
#  'semenit sebelumnya pak <EOS>',
#  'atau empat jam kemudian <EOS>',
#  'saat ia jual gelangnya demi bayar sewa <EOS>',
#  'itu yang membuatku kesal <EOS>',
#  'takut setengah mati <EOS>',
#  'jangan lakukan <EOS>',
#  'aku tidak lakukan apapun <EOS>',
#  'detik untuk membela diri <EOS>',
#  'berkas selesai <EOS>',
#  'mengetahui dia tidak meraih pistol <EOS>',
#  'segera menyerah <EOS>',
#  'pandang sang bayi <EOS>',
#  'sepenuhnya dengan pihak berwenang <EOS>',
#  'terjemahan raja james <EOS>',
#  'replika toronado bertenaga hidrogen <EOS>',
#  'patuhi aturan <EOS>',
#  'yang menarik perhatianku <EOS>',
#  'dan mungkin seorang juri <EOS>',
#  'pertimbangan klienmu sangat terganggu <EOS>',
#  'mari bahas perjanjian pembelaan <EOS>',
#  'aku melihatnya <EOS>',
#  'rahasia <EOS>',
#  'merespons menuju <EOS>',
#  'charlie apa kabar putrimu <EOS>',
#  'masih menguras uang seakan aku punya uang <EOS>',
#  'james cray <EOS>',
#  'ditembak di antara mata <EOS>',
#  'kenapa ada penghalang di rekamannya <EOS>',
#  'charlie <EOS>',
#  'bagaimana kita tahu siapa yang membunuhnya <EOS>',
#  'lihat akhirnya <EOS>',
#  'kau boleh mengakses <EOS>',
#  'rahasia <EOS>',
#  'akses diterima <EOS>',
#  'terbuka <EOS>',
#  'dia masuk ke apartemennya <EOS>',
#  'dia memeriksa harga saham <EOS>',
#  'apa aku bilang aku tak tertarik <EOS>',
#  'sialan <EOS>',
#  'siapa kau <EOS>',
#  'dia melihat yang pembunuh itu lihat <EOS>',
#  'agak tidak ketahuan <EOS>',
#  'si pembunuh meretas mata pikiran cray <EOS>',
#  'apa yang kau lakukan <EOS>',
#  'kini adalah sudut pandang si pembunuh <EOS>',
#  'dia melihat dirinya sendiri <EOS>',
#  'dan sebelum cray bisa memahami keadaan <EOS>',
#  'kumohon jangan <EOS>',
#  'kumohon <EOS>',
#  'berkas selesai <EOS>',
#  'siapa yang bisa meretas manusia <EOS>',
#  'teknologi kian canggih <EOS>',
#  'dalam artian buruk <EOS>',
#  'lihatlah metadata waktu kematiannya <EOS>',
#  'dan  detik <EOS>',
#  'berkas selesai <EOS>',
#  'astaga <EOS>',
#  'hanya meretas mata orang itu <EOS>',
#  'sendiri saat terbunuh <EOS>',
#  'atau seperti itulah kelihatannya <EOS>',
#  'tidak ada tandatanda si pembunuh <EOS>',
#  'tak ada metadata <EOS>',
#  'mau memberitahu siapa mereka <EOS>',
#  'yang memang bersalah <EOS>',
#  'kita menerima sebuah cerita detektif <EOS>',
#  'dua <EOS>',
#  'cocok dengan kasus lain <EOS>',
#  'pandangnya juga diretas <EOS>',
#  'yang juga tak ada di lokasi <EOS>',
#  'apa yang terjadi <EOS>',
#  'apa ini <EOS>',
#  'berkas selesai <EOS>',
#  'tapi kini mereka mau buka lagi kasusnya <EOS>',
#  'pengunjung terakhir adalah seorang wanita <EOS>',
#  'dihapus <EOS>',
#  'lagipula informasi ini rahasia <EOS>',
#  'ini secara resmi berupa bunuh diri <EOS>',
#  'charlie pagi ini di pusat kota <EOS>',
#  'aku melihat orang tak dikenal <EOS>',
#  'orang tak beridentitas <EOS>',
#  'tak ada jejak digital <EOS>',
#  'kudekati lagi masih kosong <EOS>',
#  'orang misterius lain <EOS>',
#  'kita melihat terlalu banyak <EOS>',
#  'atau tidak <EOS>',
#  'baik <EOS>',
#  'mengirim rekaman <EOS>',
#  'tidak diketahui  kesalahan <EOS>',
#  'kau masih bersamaku sal <EOS>',
#  'tentu saja <EOS>',
#  'tidak diketahui  kesalahan <EOS>',
#  'berkas tidak ditemukan <EOS>',
#  'sialan <EOS>',
#  'ray <EOS>',
#  'aku pergi <EOS>',
#  'apa yang kau lihat <EOS>',
#  'tunjukkan padaku yang kau lihat <EOS>',
#  'atau kau takkan melihatku lagi <EOS>',
#  'tunjukkan sal <EOS>',
#  'tidak bisa <EOS>',
#  'tidak <EOS>',
#  'apa yang kita cari lester <EOS>',
#  'kami analisa rekaman korban <EOS>',
#  'seminggu yang lalu ada sebuah suntingan <EOS>',
#  'secara teknis itu duplikasi <EOS>',
#  'agar durasinya panjang <EOS>',
#  'jika kau analisa dengan cermat <EOS>',
#  'di beberapa halaman buku <EOS>',
#  'anomali lain di rekaman ini <EOS>',
#  'saham di mata pikirannya <EOS>',
#  'dengan yang terjadi di pasar hari itu <EOS>',
#  'ini juga diperpanjang tapi <EOS>',
#  'kau tidak akan melihatnya <EOS>',
#  'ini bagus sekali <EOS>',
#  'hasil kerja yang teliti <EOS>',
#  'itu semua menutupi aktivitas yang terhapus <EOS>',
#  'aktivitas ilegal yang tak diketahui sec <EOS>',
#  'dia dibersihkan dari biaya pedagang <EOS>',
#  'dan kemudian ada ini <EOS>',
#  'musik yang diputar di kepalanya tapi <EOS>',
#  'suara itu <EOS>',
#  'cray kedatangan tamu misteri <EOS>',
#  'tak ada bukti pertemuan <EOS>',
#  'latar belakang korban <EOS>',
#  'menyunting rekamannya sendiri jadi <EOS>',
#  'dia menyewa peretas <EOS>',
#  'jordan nees juga disunting <EOS>',
#  'riwayat kecanduan heroin <EOS>',
#  'menghapus rekaman kambuhnya yang terbaru <EOS>',
#  'agar ia tak kehilangan pekerjaan <EOS>',
#  'ini mimpi buruk <EOS>',
#  'hipotetisnya tidak <EOS>',
#  'mereka tak hanya bisa masuk ke rumahnya <EOS>',
#  'mereka juga memindahkan furnitur <EOS>',
#  'kemarin di south william <EOS>',
#  'terakhir yang melihat nees hidup <EOS>',
#  'semalam ia dihapus dari historiku <EOS>',
#  'tapi yang lain tidak hilang <EOS>',
#  'hidupku dan menghapusnya rekamannya <EOS>',
#  'kirimkan kembali padaku <EOS>',
#  'aku mau tanyakan hal yang sama <EOS>',
#  'punyaku juga hilang <EOS>',
#  'tahun siswa <EOS>',
#  'gamer  sering bolos <EOS>',
#  'saat kulihat dia <EOS>',
#  'kini hanyalah rekaman rusak <EOS>',
#  'berkas tidak ditemukan <EOS>',
#  'tak hanya aku <EOS>',
#  'hari itu rekamannya juga disunting <EOS>',
#  'saat mereka melihat dia <EOS>',
#  'orang asing secara acak <EOS>',
#  'dia pasti membuat algoritma <EOS>',
#  'dan menghapus jejak apapun yang ditemukan <EOS>',
#  'ia tak terlihat dan celahpun tercipta <EOS>',
#  'tak ada satupun orang di jalanan <EOS>',
#  'untuk buktikan penyamaran resmi <EOS>',
#  'dan orang yang menyamar biasanya mati <EOS>',
#  'ingatan tanpa menghapus mereka <EOS>',
#  'yang cukup cerdas untuk ini <EOS>',
#  'tapi terlalu cerdas untuk membantai <EOS>',
#  'kecuali yang berbakat tidak waras <EOS>',
#  'mereka sudah periksa kamera pengawas <EOS>',
#  'tak terdeteksi <EOS>',
#  'sialan <EOS>',
#  'tidak ada nama wajah <EOS>',
#  'kita tak tahu ke mana dia <EOS>',
#  'ya <EOS>',
#  'kita tak dapat apapun <EOS>',
#  'lapar <EOS>',
#  'tidak <EOS>',
#  'kau sudah sampai <EOS>',
#  'menghubungi kristen <EOS>',
#  'hei <EOS>',
#  'hai sal <EOS>',
#  'ini sudah larut aku tahu <EOS>',
#  'besok ulang tahunnya <EOS>',
#  'pikirmu aku tidak tahu <EOS>',
#  'sepuluh tahun <EOS>',
#  'tolong hentikan dia sudah tiada <EOS>',
#  'dia akan berusia sepuluh tahun <EOS>',
#  'untuk kau dan aku <EOS>',
#  'lakukan apa <EOS>',
#  'apa salahnya <EOS>',
#  'kenangannya tidak akan ke manamana <EOS>',
#  'dari kelihatannya begitu juga kau <EOS>',
#  'sal <EOS>',
#  'panggilan tiap kali kita bicara <EOS>',
#  'conrad aku tidak akan lama hanya saja <EOS>',
#  'aku tahu <EOS>',
#  'tapi kau tidak bisa selalu menelpon <EOS>',
#  'dia bukan lagi istrimu <EOS>',
#  'ini ulang tahunnya <EOS>',
#  'kristen <EOS>',
#  'kau mabuk <EOS>',
#  'kau tidak stabil <EOS>',
#  'aku tidak mabuk <EOS>',
#  'sudah berharihari aku tidak minum <EOS>',
#  'terakhir di rekamanmu <EOS>',
#  'kau tahu <EOS>',
#  'aku harus pergi <EOS>',
#  'rahasia <EOS>',
#  'merespons menuju <EOS>',
#  'tolong <EOS>',
#  'kumohon bunuh saja aku <EOS>',
#  'jangan sakiti dia <EOS>',
#  'kumohon jangan <EOS>',
#  'jangan <EOS>',
#  'berkas selesai <EOS>',
#  'mata pikiran dibajak <EOS>',
#  'keduanya <EOS>',
#  'pak masalahnya sudut pandang pelaku <EOS>',
#  'tidak ada jejak <EOS>',
#  'tak perlu beritahu <EOS>',
#  'responden pertama <EOS>',
#  'aku ada di dekat sini pak <EOS>',
#  'mana semua orang <EOS>',
#  'dalam perjalanan <EOS>',
#  'siapa lagi yang ada di sini <EOS>',
#  'pengurus rumah <EOS>',
#  'dia di lantai bawah <EOS>',
#  'darurat <EOS>',
#  'dia kembali ke kamarnya <EOS>',
#  'dia syok <EOS>',
#  'aku sudah bicara padanya <EOS>',
#  'bu bisa jelaskan rupa pengunjungnya <EOS>',
#  'berambut cokelat panjang <EOS>',
#  'usia  tahun <EOS>',
#  'aku hanya melihatnya sebentar <EOS>',
#  'dia di rumah ini sekarang <EOS>',
#  'itu tikus yang besar <EOS>',
#  'ada kita berempat di dalam rumah <EOS>',
#  'satu dari kita begitu malu <EOS>',
#  'kunci pemancarmu <EOS>',
#  'pelacak meta dinonaktifkan <EOS>',
#  'tidak ada tandatanda vital <EOS>',
#  'minta bantuan <EOS>',
#  'sial <EOS>',
#  'detik <EOS>',
#  'kumohon bunuh saja aku <EOS>',
#  'jangan sakiti dia <EOS>',
#  'kumohon jangan <EOS>',
#  'jangan <EOS>',
#  'berkas selesai <EOS>',
#  'pasangan lesbian <EOS>',
#  'hubungan mereka disembunyikan <EOS>',
#  'satunya <EOS>',
#  'dalam kampanye eleksi ulang <EOS>',
#  'di minggu sebelumnya <EOS>',
#  'mereka dalam rekaman <EOS>',
#  'demi menjaga nama baiknya <EOS>',
#  'tidak mudah dilakukan <EOS>',
#  'berkencan selama setahun <EOS>',
#  'kita mulai dapat gambaran peretas kita <EOS>',
#  'meski kita tidak punya gambarnya <EOS>',
#  'hidup di ether <EOS>',
#  'mencari nafkah dengan menutupi kejahatan <EOS>',
#  'rahasia perselingkuhan <EOS>',
#  'kejahatan tanpa korban <EOS>',
#  'menyatukan alibi yang dapat dipercaya <EOS>',
#  'diinginkan dalam rekaman <EOS>',
#  'yang terpenting dia hapus data dirinya <EOS>',
#  'kini kliennya juga dihapus <EOS>',
#  'untuk apa repotrepot bertemu klien <EOS>',
#  'dia bisa lakukan dari jauh <EOS>',
#  'bolakbalik meninggalkan jejak <EOS>',
#  'dan bisa disadap <EOS>',
#  'valuta yang tak bisa diretas tunai <EOS>',
#  'ingat tunai <EOS>',
#  'soal sentuhan pribadi <EOS>',
#  'jejaknya tak terdaftar tapi cocok <EOS>',
#  'dia dekat dengan korban <EOS>',
#  'itukah masalahnya <EOS>',
#  'tidak ada yang mau cerita kisah cintanya <EOS>',
#  'pasti bukan yang pertama <EOS>',
#  'ia tiduri berujung pada kematian <EOS>',
#  'satu cara untuk membunuhmu <EOS>',
#  'semalam saat aku mengejarnya <EOS>',
#  'mengirim rekaman <EOS>',
#  'di situlah bermulanya <EOS>',
#  'dia mengubah pandanganku <EOS>',
#  'tangganya <EOS>',
#  'tangga lebar <EOS>',
#  'mereka terlihat biasa saja <EOS>',
#  'tidak bagiku itu ilusi penglihatan <EOS>',
#  'belum berakhir di situ <EOS>',
#  'saat ini <EOS>',
#  'aku melihat <EOS>',
#  'kereta di peron <EOS>',
#  'kereta yang tidak ada di situ <EOS>',
#  'sumpah <EOS>',
#  'kereta asli bisa saja membunuhku <EOS>',
#  'menempatkan gambar bergerak <EOS>',
#  'ke dalam rekaman langsung <EOS>',
#  'itu mungkin <EOS>',
#  'bagaimana cara kita hentikan si jalang ini <EOS>',
#  'korban sebelum terbunuh <EOS>',
#  'kita sewa dia <EOS>',
#  'aku akan jadi umpan <EOS>',
#  'aku akan menyamar <EOS>',
#  'wanita itu suka para petinggi <EOS>',
#  'bekerja di rumah pialang <EOS>',
#  'tunangan riwayat profil palsu <EOS>',
#  'menampilkan bahwa aku orang sukses <EOS>',
#  'menutupi karier penegak hukumku <EOS>',
#  'tahun penari menganggur <EOS>',
#  'tahun pialang saham <EOS>',
#  'tahun desainer <EOS>',
#  'tahun penata rambut <EOS>',
#  'bagi siapapun yang menyelidikiku <EOS>',
#  'lester harus ada dalam rencana <EOS>',
#  'dia harusnya aman <EOS>',
#  'terbuka <EOS>',
#  'yang diriku yang baru ingin hapus <EOS>',
#  'tahun prostitusi <EOS>',
#  'prostitusi berkelas tinggi <EOS>',
#  'terima kasih <EOS>',
#  'minum <EOS>',
#  'aku tidak minum <EOS>',
#  'apa yang kau suka lakukan <EOS>',
#  'ya <EOS>',
#  'terima kasih <EOS>',
#  'berdosa usai bercinta dengan pelacur <EOS>',
#  'kuhubungi tunanganku <EOS>',
#  'alison ann <EOS>',
#  'pacarku akan meminta rekamanku <EOS>',
#  'jadi kucoba hubungi peretas kita <EOS>',
#  'yang digunakan korban lainnya <EOS>',
#  'kita tahu metodenya <EOS>',
#  'dia akan mendatangiku <EOS>',
#  'cocok dengan deskripsi <EOS>',
#  'sol grayson <EOS>',
#  'bedah kosmetik <EOS>',
#  'aku berubah pikiran <EOS>',
#  'membalas sol <EOS>',
#  'anonim <EOS>',
#  'halo sol kau butuh apa <EOS>',
#  'bisa bertemu <EOS>',
#  'malam ini pukul sebelas <EOS>',
#  'bagaimana caraku menemukanmu <EOS>',
#  'di tempat terbuka <EOS>',
#  'aku butuh banyak uang <EOS>',
#  'jadi jangan ada polisi di dekatku <EOS>',
#  'tanpa membocorkan penyamaranku <EOS>',
#  'kita gunakan sinyal <EOS>',
#  'jangan lihat aku <EOS>',
#  'grayson pialang saham <EOS>',
#  'aku mau singkirkan sebuah perselingkuhan <EOS>',
#  'aku tidak peduli <EOS>',
#  'hanya tunai <EOS>',
#  'akan mengganggu kita <EOS>',
#  'apartemenmu <EOS>',
#  'perlu membuat dia cukup dekat <EOS>',
#  'bagi lester untuk memindai frekuensinya <EOS>',
#  'hingga rekaman pembunuhannya <EOS>',
#  'kita tangkap dia <EOS>',
#  'minum <EOS>',
#  'aku sudah masuk <EOS>',
#  'secepat itu <EOS>',
#  'kita mulai <EOS>',
#  'begini cara kerjanya <EOS>',
#  'percaya atau tidak aku punya kebijakan <EOS>',
#  'untuk menghargai privasimu <EOS>',
#  'yang kau ingin aku lihat <EOS>',
#  'tak lebih <EOS>',
#  'kecuali kau mau mengelabuiku <EOS>',
#  'jika lakukan itu <EOS>',
#  'dan kau akan mati <EOS>',
#  'terdengar adil <EOS>',
#  'jadi <EOS>',
#  'seminggu yang lalu <EOS>',
#  'hari senin <EOS>',
#  'sekitar pukul  sampai <EOS>',
#  'aku melihatnya <EOS>',
#  'itu wanita yang ingin kau hapus <EOS>',
#  'ya <EOS>',
#  'aku bisa buat celah <EOS>',
#  'dan lihat kalau itu sudah hilang <EOS>',
#  'wanita yang mau melihat ulang <EOS>',
#  'dia bisa gunakan untuk melawanmu <EOS>',
#  'berkas tidak ditemukan <EOS>',
#  'ya <EOS>',
#  'untuk mengisi kekosongannya <EOS>',
#  'aku tidur lebih awal <EOS>',
#  'pacarmu usai pelacur itu pergi <EOS>',
#  'ya <EOS>',
#  'pacarmu melihat pertemuan itu <EOS>',
#  'dia akan lihat kau tidak menelpon <EOS>',
#  'minum di bar <EOS>',
#  'terlalu banyak orang <EOS>',
#  'mempersulit keadaan <EOS>',
#  'kau sendiri di apartemenmu <EOS>',
#  'kau sendiri di apartemen <EOS>',
#  'untungnya ada beberapa untuk dipilih <EOS>',
#  'tak heran kau menyewa pelacur <EOS>',
#  'akan kutampilkan yang kulakukan <EOS>',
#  'aku harus perbaiki semua yang kau lihat <EOS>',
#  'seberapa cemburunya pacarmu <EOS>',
#  'terutama pembetul gambar <EOS>',
#  'kecuali aku di sini higga pekan depan <EOS>',
#  'hal terburuk di dunia <EOS>',
#  'kau tidak bisa membayarku <EOS>',
#  'ya <EOS>',
#  'bisnis lancar <EOS>',
#  'orang ingin anggap tak pernah terjadi <EOS>',
#  'pernah menolak pekerjaan <EOS>',
#  'menolong orang kabur dari pembunuhan <EOS>',
#  'tergantung siapa yang dibunuh <EOS>',
#  'sampai ketemu lagi <EOS>',
#  'aku juga harus menghapusku dari hidupmu <EOS>',
#  'malam ini <EOS>',
#  'di mana kau <EOS>',
#  'dan tak kulihat apapun <EOS>',
#  'tidak ada nama <EOS>',
#  'tidak ada data nihil <EOS>',
#  'pasti kau sering dipandang <EOS>',
#  'aku jarang keluar <EOS>',
#  'saat aku keluar aku tak membuka diri <EOS>',
#  'orang pikir itu kesalahan <EOS>',
#  'kenapa tidak memakai nama lain <EOS>',
#  'aku tidak mau ada sebagai orang lain <EOS>',
#  'aku tidak mau ada <EOS>',
#  'kau punya nama <EOS>',
#  'benar <EOS>',
#  'itu saja <EOS>',
#  'tapi aku ada pelanggan lain <EOS>',
#  'bagaimana dengan orang yang mengingatmu <EOS>',
#  'seperti aku <EOS>',
#  'kau tidak bisa menghapus ingatan <EOS>',
#  'aku bisa pikirkan cara <EOS>',
#  'untuk membawa pistol itu <EOS>',
#  'berputar <EOS>',
#  'lihat ke sisi lain <EOS>',
#  'jangan cemas <EOS>',
#  'tentangku dalam rekamanmu <EOS>',
#  'sampai terakhir kali kau melihatku <EOS>',
#  'sekarang <EOS>',
#  'sal <EOS>',
#  'aku dapat proxynya yang kelima <EOS>',
#  'aku tak mendapat rekamannya <EOS>',
#  'belum <EOS>',
#  'kenapa dia tidak membunuhmu <EOS>',
#  'maaf mengecewakanmu charlie <EOS>',
#  'benar kalian tidak berhubungan badan <EOS>',
#  'kurasa aku bukan tipenya <EOS>',
#  'dia takkan melihat rekamanmu <EOS>',
#  'saham berubah jadi polisi <EOS>',
#  'kurasa tidak <EOS>',
#  'dia bilang sesuatu <EOS>',
#  'melihat yang kau ingin aku lihat <EOS>',
#  'pembunuh berantai dengan prinsip <EOS>',
#  'entah kenapa <EOS>',
#  'aku percaya padanya <EOS>',
#  'bala bantuan <EOS>',
#  'unit komputer <EOS>',
#  'rekomendasi pribadi komisaris <EOS>',
#  'ya ampun <EOS>',
#  'sal cyrus frear <EOS>',
#  'hai <EOS>',
#  'hai <EOS>',
#  'tahun spesialis keamanan biro <EOS>',
#  'kita masuk <EOS>',
#  'kita akan lakukan apa <EOS>',
#  'kita hanya bisa lihat dari matanya <EOS>',
#  'apa yang ia lakukan sekarang <EOS>',
#  'sampai kita lacak rantai proxynya <EOS>',
#  'fokus temukan petunjuk <EOS>',
#  'itu tak hentikan kita <EOS>',
#  'abad pertengahan yang mahal <EOS>',
#  'apartemen loft pusat kota <EOS>',
#  'kotrek kuningan padat antik italia <EOS>',
#  'adalah saat ia aktif di ether <EOS>',
#  'kita temukan dia <EOS>',
#  'dicampur wiski scotch <EOS>',
#  'cocok dengan pelaku <EOS>',
#  'usai kau menembaknya <EOS>',
#  'mata pikiran tak dapat apaapa <EOS>',
#  'kurasa wanita ini tidak daring <EOS>',
#  'dia teliti ke mana ia melihat <EOS>',
#  'dia masuk ke ether <EOS>',
#  'bagaimana dia bisa lewati protokol <EOS>',
#  'nampaknya bukan masalah baginya <EOS>',
#  'dia masuk ke rekamannya <EOS>',
#  'dia sedang melihat mata siapa <EOS>',
#  'jesper nix penjual karya seni bodoh <EOS>',
#  'dua galeri di upper east side <EOS>',
#  'siapa dia <EOS>',
#  'max keener  tahun <EOS>',
#  'pemalsu mantan narapidana <EOS>',
#  'lukisannya <EOS>',
#  'aku tahu apa itu <EOS>',
#  'keaslian tidak dapat terkonfirmasi <EOS>',
#  'jesper nakal <EOS>',
#  'jesper dengan pemalsu itu <EOS>',
#  'menemukan karya seni berharga ini <EOS>',
#  'astaga indahnya <EOS>',
#  'dia sudah keluar <EOS>',
#  'kau melacaknya <EOS>',
#  'proxy <EOS>',
#  'yang terakhir anonim <EOS>',
#  'digunakan peretas proxy untuk sembunyi <EOS>',
#  'kerja bagus menyambungkan titiktitiknya <EOS>',
#  'tidak sampai dia tertangkap <EOS>',
#  'kau hidup untuk bercerita <EOS>',
#  'menjual lukisan palsunya <EOS>',
#  'ya pak <EOS>',
#  'kami mengamatinya semalaman <EOS>',
#  'kami masih tak tahu lokasinya <EOS>',
#  'kalian harus fokus <EOS>',
#  'dia memang analog <EOS>',
#  'kuharap dia melihat keluar jendela <EOS>',
#  'akhirnya <EOS>',
#  'sinyal hilang <EOS>',
#  'dia pergi ke mana <EOS>',
#  'kita kehilangan dia <EOS>',
#  'rantai proxynya <EOS>',
#  'tautannya dinonaktifkan <EOS>',
#  'memulai rantai baru <EOS>',
#  'ini biasa <EOS>',
#  'dia melihat kita <EOS>',
#  'tidak <EOS>',
#  'dia suka telur mata sapi <EOS>',
#  'pak <EOS>',
#  'ada apa nix menjual salah satu lukisannya <EOS>',
#  'kita tak perlu cemaskan itu lagi pak <EOS>',
#  'nix tewas <EOS>',
#  'metode yang sama <EOS>',
#  'sudut pandang pembunuh <EOS>',
#  'apa maumu <EOS>',
#  'apa kau gila <EOS>',
#  'apa maumu <EOS>',
#  'apa maumu <EOS>',
#  'apa maumu <EOS>',
#  'berkas selesai <EOS>',
#  'mereka baru kirim dari tkp <EOS>',
#  'kasus ini <EOS>',
#  'kini menjadi prioritas <EOS>',
#  'kami paham komisaris <EOS>',
#  'aku tak tahu apa kau paham detektif <EOS>',
#  'lima pembunuhan <EOS>',
#  'bukan soal pembunuhannya <EOS>',
#  'ini kasus pembunuhan <EOS>',
#  'level keanoniman ini <EOS>',
#  'membuat semua kejahatan memungkinkan <EOS>',
#  'memperluas sistem keamanan <EOS>',
#  'korban <EOS>',
#  'kita menerima laporan tiap harinya <EOS>',
#  'hantu orang misterius <EOS>',
#  'terserah kau menyebutnya apa <EOS>',
#  'integritas sistemnya terancam <EOS>',
#  'integritas <EOS>',
#  'kita mengandalkan transparansi <EOS>',
#  'yang tak bisa dilihat <EOS>',
#  'kita butuh identitas pasti <EOS>',
#  'ini bukan kasus terpencil <EOS>',
#  'kami percaya ada sekumpulan orang <EOS>',
#  'yang mungkin tak saling mengenal <EOS>',
#  'diri mereka dan yang lain <EOS>',
#  'aku tidak peduli <EOS>',
#  'korbannya sudah tidak ada <EOS>',
#  'aku peduli kalau dia tidak ada <EOS>',
#  'yang kumau dia bunuh dirinya sendiri <EOS>',
#  'aku mengerti <EOS>',
#  'itu tidak penting <EOS>',
#  'tapi dia tak punya kehidupan itu penting <EOS>',
#  'ya <EOS>',
#  'kini kau paham <EOS>',
#  'kita butuh proxy pertama di rantai baru <EOS>',
#  'kau akan menyamar lagi <EOS>',
#  'dengan komisaris polisi <EOS>',
#  'membocorkan penyamaranku <EOS>',
#  'baru tiga hari <EOS>',
#  'kami akan pasang tambalan <EOS>',
#  'kau berada di rumah pialang <EOS>',
#  'jika dia tidak melihat ulang <EOS>',
#  'mungkin dia tidak akan sadar <EOS>',
#  'aku pelanggan setia <EOS>',
#  'mungkin dia menyukaimu <EOS>',
#  'dia juga suka meledakkan otak orang <EOS>',
#  'kau dengar perkataan kenik <EOS>',
#  'kepentingan komersial di sini <EOS>',
#  'jauh di atas bayaran kita <EOS>',
#  'anonimitas adalah musuh <EOS>',
#  'cara dia melakukannya dan <EOS>',
#  'mengungkap dirinya <EOS>',
#  'sama saja <EOS>',
#  'agar dia tidak merasa takut <EOS>',
#  'tuantuan <EOS>',
#  'saat kalian buat tambalan <EOS>',
#  'usahakan buat sebagus miliknya <EOS>',
#  'papan pesan <EOS>',
#  'halo sol <EOS>',
#  'tidak diketahui  kesalahan <EOS>',
#  'kokain  gram <EOS>',
#  'alasan untuk menemuiku lagi <EOS>',
#  'kau tidak suka bisnis yang terulang <EOS>',
#  'kenapa kau belum lakukan <EOS>',
#  'aku menunggu acara khusus <EOS>',
#  'adegan selagi kulakukan ini <EOS>',
#  'bisa kutukar penjualnya dengan pelacur <EOS>',
#  'aku tidak suka anjing <EOS>',
#  'atau tidak ada sama sekali <EOS>',
#  'punya kemampuan sama <EOS>',
#  'orang yang tidak ada <EOS>',
#  'bagaimana bisa <EOS>',
#  'tak perlu kusunting penjualnya <EOS>',
#  'dia tidak pernah melihatmu <EOS>',
#  'melakukannya secara buta <EOS>',
#  'menangis mencium bermimpi <EOS>',
#  'atau melanggar hukum <EOS>',
#  'kau bisa tetap anonim <EOS>',
#  'hanya saja itu sulit sekali <EOS>',
#  'kenapa lakukan ini untuk bayar tagihan <EOS>',
#  'untuk apa lagi <EOS>',
#  'kau pasti punya rencana khusus <EOS>',
#  'kau salah orang <EOS>',
#  'mudah <EOS>',
#  'aku berusaha tidak terlihat <EOS>',
#  'tapi jika kau tanya apa itu buruk <EOS>',
#  'ya kurasa itu buruk <EOS>',
#  'kata mereka itu demi keamanan kita <EOS>',
#  'kenapa aku tidak merasa aman <EOS>',
#  'sudah berapa lama kau tidak ada <EOS>',
#  'kau terlalu banyak bertanya <EOS>',
#  'kau tidak menjawabnya <EOS>',
#  'tahun <EOS>',
#  'tidak kaya ataupun bijak <EOS>',
#  'kesempatan sekali seumur hidup <EOS>',
#  'aku tak berhenti sampai semua hilang <EOS>',
#  'dalam banyak cara bukti analog <EOS>',
#  'yang sulit dilacak dan dihapus <EOS>',
#  'dfe <EOS>',
#  'hapus semuanya <EOS>',
#  'aku tak pernah bahagia di ruang besar <EOS>',
#  'ruang besar <EOS>',
#  'dunia luar <EOS>',
#  'ruang terbuka <EOS>',
#  'bagian dari planet yang bukan dunia maya <EOS>',
#  'kau tahu itu ilegal <EOS>',
#  'kau yakin punya pacar sol <EOS>',
#  'lagakmu seperti pria lajang <EOS>',
#  'ada hal lain yang mau kau lakukan <EOS>',
#  'yang bisa kuhapus <EOS>',
#  'aku harus menghapusnya <EOS>',
#  'hapus semuanya <EOS>',
#  'terutama berhubungan badannya <EOS>',
#  'kau sungguh tak suka melihat ulang ya <EOS>',
#  'seperti kau <EOS>',
#  'tahun wakil petugas <EOS>',
#  'tahun detektif kelas satu <EOS>',
#  'meminta bala bantuan <EOS>',
#  'aktivitas otak berhenti <EOS>',
#  'detektif kelas satu <EOS>',
#  'apa yang telah kau perbuat <EOS>',
#  'kau memang tak bisa <EOS>',
#  'siapa dirimu sebenarnya <EOS>',
#  'dia tewas <EOS>',
#  'harusnya kau sudah pikirkan <EOS>',
#  'jangan berusaha mencariku <EOS>',
#  'kau mencariku maka kau mati <EOS>',
#  'berkas selesai <EOS>',
#  'kau biarkan dia kabur <EOS>',
#  'dan membunuh lester dalam perjalanannya <EOS>',
#  'entah apa kau bisa memperbaikinya sal <EOS>',
#  'dia bisa menembus kita <EOS>',
#  'rekamannya sendiri <EOS>',
#  'pulanglah <EOS>',
#  'ambil cuti <EOS>',
#  'buka kunci <EOS>',
#  'papan pesan <EOS>',
#  'minumlah itu akan membantu <EOS>',
#  'kini aku bisa melihat dari matamu <EOS>',
#  'lebih pas dengan gayamu <EOS>',
#  'tahu aku bicara pada siapa <EOS>',
#  'kau tidak tahu itu sebabnya ini seru <EOS>',
#  'aku akan menghentikanmu <EOS>',
#  'kau belum melihat semuanya <EOS>',
#  'maafkan aku <EOS>',
#  'maafkan aku <EOS>',
#  'maafkan aku <EOS>',
#  'aku berpaling darinya sebentar <EOS>',
#  'sebentar <EOS>',
#  'ya itu dia <EOS>',
#  'berkas selesai <EOS>',
#  'berkas tidak ditemukan <EOS>',
#  'berkas tidak ditemukan <EOS>',
#  'berkas tidak ditemukan <EOS>',
#  'berkas tidak ditemukan <EOS>',
#  'menghubungi kristen <EOS>',
#  'kristen hai sal <EOS>',
#  'kirimkan ingatanmu tentang salvador <EOS>',
#  'apa <EOS>',
#  'tidak <EOS>',
#  'aku tak mau mengingatnya itu menyakitkan <EOS>',
#  'apapun <EOS>',
#  'kenapa untuk apa <EOS>',
#  'punyaku hilang <EOS>',
#  'hilang <EOS>',
#  'baiklah <EOS>',
#  'sialan <EOS>',
#  'sal ingatannya hilang <EOS>',
#  'dia hilang <EOS>',
#  'apa yang terjadi <EOS>',
#  'sal <EOS>',
#  'sal <EOS>',
#  'sal <EOS>',
#  'sal <EOS>',
#  'aku thomas <EOS>',
#  'thomas devry <EOS>',
#  'memanggil lift <EOS>',
#  'sampai <EOS>',
#  'injak rem <EOS>',
#  'berhenti sekarang <EOS>',
#  'lihat sekeliling demi keamanan <EOS>',
#  'semua aman harap lanjutkan <EOS>',
#  'sudah kubilang untuk cuti sal <EOS>',
#  'tinggalkan semuanya <EOS>',
#  'dia tidak mau meninggalkanku <EOS>',
#  'dia terus membajak mataku <EOS>',
#  'aku tak tahu apa yang kulihat <EOS>',
#  'aku tak percaya yang kulihat <EOS>',
#  'bukanlah metafora <EOS>',
#  'aku takut untuk tidur <EOS>',
#  'tak bisa sembunyi dia tahu aku di mana <EOS>',
#  'semuanya <EOS>',
#  'putraku salvador <EOS>',
#  'semua kenangan indahnya hilang <EOS>',
#  'apa yang terjadi <EOS>',
#  'berulangulang kali <EOS>',
#  'yakin kau tidak melihat halhal aneh <EOS>',
#  'itulah intinya <EOS>',
#  'kami menyewa lebih banyak peretas <EOS>',
#  'seperti dia <EOS>',
#  'apalagi yang bisa kami lakukan <EOS>',
#  'seperti katamu <EOS>',
#  'semuanya rentan <EOS>',
#  'sial <EOS>',
#  'aku tak lagi menjawab panggilan komisaris <EOS>',
#  'kita yang mengawasi bukan mereka <EOS>',
#  'kita tak terdeteksi <EOS>',
#  'bagaimana caraku menghentikannya charlie <EOS>',
#  'kau temukan dia <EOS>',
#  'maka akan berhenti <EOS>',
#  'kuharap lester masih hidup <EOS>',
#  'peringatan di ether <EOS>',
#  'perintah untuk menangkap detektif frieland <EOS>',
#  'karena penembakan thomas devry <EOS>',
#  'segera menyerah <EOS>',
#  'dia tinggal di apartemenku dia tetanggaku <EOS>',
#  'berkas selesai <EOS>',
#  'aku tidak menembaknya <EOS>',
#  'kelihatannya kau menembaknya <EOS>',
#  'yang terlihat bisa menipu <EOS>',
#  'peluru dari mmmu ditemukan di dinding <EOS>',
#  'semua menunjukkan itu ulahmu <EOS>',
#  'kau sudah lihat otopsinya <EOS>',
#  'kepala koroner <EOS>',
#  'lubang dalam dirimu seperti itu <EOS>',
#  'hasilnya belum pasti <EOS>',
#  'itu manipulasi buatan itu palsu <EOS>',
#  'tidak ada bukti bahwa itu palsu <EOS>',
#  'dan tak ada bukti menyatakan itu asli <EOS>',
#  'kita tak boleh anggap semuanya palsu <EOS>',
#  'kita harus percaya mata kita <EOS>',
#  'atau sistemnya tidak bekerja <EOS>',
#  'itu ulahnya <EOS>',
#  'dia ingin aku keluar dari kasus ini <EOS>',
#  'keinginannya terkabul <EOS>',
#  'kau diskors menunggu penyelidikan <EOS>',
#  'ditahan di rumah <EOS>',
#  'diawasi  jam <EOS>',
#  'terasa aneh pak <EOS>',
#  'mengawasimu <EOS>',
#  'kalau begitu jangan <EOS>',
#  'menara metropolitan life company <EOS>',
#  'kau memang polisi <EOS>',
#  'semua memandangku <EOS>',
#  'kau mengganggu <EOS>',
#  'kau ingat <EOS>',
#  'ada suatu hal di pantulannya <EOS>',
#  'diam di tempat <EOS>',
#  'turunkan senjatamu sal <EOS>',
#  'aku bisa lihat yang kau lihat <EOS>',
#  'tapi kau sudah lihat tempat ini <EOS>',
#  'bagaimana <EOS>',
#  'kalian suka yang kalian lihat <EOS>',
#  'kau akan membuka dirimu <EOS>',
#  'terlalu banyak bekerja <EOS>',
#  'kenapa <EOS>',
#  'kenapa kau lakukan ini padaku <EOS>',
#  'ini bukan ulahku <EOS>',
#  'membuatnya seolah karena ulahku <EOS>',
#  'aku tak tahu siapa dia <EOS>',
#  'aku mau tunjukkan sesuatu <EOS>',
#  'rekamanku <EOS>',
#  'waktu kematiannya <EOS>',
#  'lester <EOS>',
#  'mengirim rekaman <EOS>',
#  'seolah itu karena ulahku <EOS>',
#  'maksudmu peretas diretas <EOS>',
#  'mata kita sekarang mata kita <EOS>',
#  'aku tidak aman di manapun <EOS>',
#  'begitu juga kau <EOS>',
#  'bersamaku yang masih hidup <EOS>',
#  'bagaimana aku tahu kau tidak berbohong <EOS>',
#  'tunjukkan sungguh rekaman aslimu <EOS>',
#  'kau tidak tahu <EOS>',
#  'mana yang tak kau pahami <EOS>',
#  'kau kunci metamu <EOS>',
#  'menyerang sesama petugas <EOS>',
#  'tak bisa kita identifikasi <EOS>',
#  'mungkin bukan karena rusak <EOS>',
#  'mungkin itu tidak terdaftar <EOS>',
#  'orang misterius lain <EOS>',
#  'atau itu mungkin rusak <EOS>',
#  'saat lester dibunuh <EOS>',
#  'dia tidak di sana saat pistol ditembakkan <EOS>',
#  'kini di mana dia <EOS>',
#  'kau pasti menahannya untuk diinterogasi <EOS>',
#  'kurasa itu bukan ulahnya <EOS>',
#  'kenapa <EOS>',
#  'karena kau menidurinya <EOS>',
#  'seperti semua retasannya <EOS>',
#  'tidak membuktikan apapun <EOS>',
#  'itu membuktikan semuanya <EOS>',
#  'dia mainmain denganmu sal <EOS>',
#  'menunggu sidang departemen <EOS>',
#  'semua hak akses dicabut <EOS>',
#  'kami mengawasimu <EOS>',
#  'kau harusnya terima kasih <EOS>',
#  'dia sedang apa <EOS>',
#  'tidak melakukan apapun <EOS>',
#  'pengulangan <EOS>',
#  'papan pesan <EOS>',
#  'hai sal aku ingin bersamamu <EOS>',
#  'malam ini <EOS>',
#  'mereka mengawasiku <EOS>',
#  'itu yang mereka percaya <EOS>',
#  'mereka di luar apartemenku <EOS>',
#  'tidak lama <EOS>',
#  'peringatan petugas tewas <EOS>',
#  'semua unit merespons <EOS>',
#  'tersangka bersenjata dan berbahaya <EOS>',
#  'sialan <EOS>',
#  'kenapa kau lakukan itu <EOS>',
#  'aku masuk perangkap <EOS>',
#  'tapi aku lupa melihat matamu <EOS>',
#  'kini kalian bisa melihat melalui mataku <EOS>',
#  'kenapa <EOS>',
#  'kenapa kau lakukan ini <EOS>',
#  'semuanya sempurna <EOS>',
#  'kita tak ditakdirkan untuk bertemu <EOS>',
#  'siapa kau <EOS>',
#  'aku tahu siapa kau <EOS>',
#  'kau temukan aku di ether <EOS>',
#  'tidak kau yang temukan aku <EOS>',
#  'kau proxy anonim itu <EOS>',
#  'yang terakhir di rantai <EOS>',
#  'kau menjagaku <EOS>',
#  'menuntun mereka padamu <EOS>',
#  'kujauhkan mereka <EOS>',
#  'kau melihat rekamanku <EOS>',
#  'kau tahu bagaimana aku sembunyi <EOS>',
#  'algoritmanya brilian <EOS>',
#  'sungguh <EOS>',
#  'aku tahu betapa inginnya kau menghilang <EOS>',
#  'kau hapus rekaman <EOS>',
#  'tapi kau tak bisa hapus ingatan <EOS>',
#  'aku bisa <EOS>',
#  'tidak <EOS>',
#  'membuatnya seolah tak terjadi <EOS>',
#  'kau bisa menghilang <EOS>',
#  'kita bisa <EOS>',
#  'tidak <EOS>',
#  'kini sudah berbeda <EOS>',
#  'kenapa kau membuatnya seolah itu ulahku <EOS>',
#  'kita bersama <EOS>',
#  'berkas selesai <EOS>',
#  'rekamannya hilang <EOS>',
#  'kau tidak tahu siapa cyrus frear <EOS>',
#  'dia pekerjamu <EOS>',
#  'kau yang rekomendasikan <EOS>',
#  'sungguh <EOS>',
#  'ya <EOS>',
#  'dia membuatnya seolah itu dariku <EOS>',
#  'gadis itu <EOS>',
#  'di mana dia <EOS>',
#  'siapa dia <EOS>',
#  'kau tidak akan mencari <EOS>',
#  'lihat aku <EOS>',
#  'maafkan aku <EOS>',
#  'tanpa diketahui olehnya <EOS>',
#  'adalah membiarkan dia menemukanmu <EOS>',
#  'kau harus perbaiki pemilihan waktunya <EOS>',
#  'itu hampir saja <EOS>',
#  'kami temukan identitasmu <EOS>',
#  'hidupmu <EOS>',
#  'itu baru awalnya <EOS>',
#  'semua orang yang pernah bersamaku <EOS>',
#  'dia tak ingin aku begitu <EOS>',
#  'jadi orang lain tidak bisa memilikiku <EOS>',
#  'caramu melakukannya <EOS>',
#  'bagaimana kau menghilang <EOS>',
#  'tahu harus melihat ke mana <EOS>',
#  'kau sudah miliki rekamanku <EOS>',
#  'mereka memilikinya <EOS>',
#  'kuberikan pada kalian semua <EOS>',
#  'algoritmanya <EOS>',
#  'memisahkan hidupku menjadi pecahan detik <EOS>',
#  'acak dalam rekaman semua orang <EOS>',
#  'tapi jika kau mencoba mencari detikku <EOS>',
#  'lewat tanpa kau ketahui <EOS>',
#  'menyatukan seluruh hidupku lagi <EOS>',
#  'jika kau ingin melihat ulang <EOS>',
#  'semuanya sebelum kau sadari <EOS>',
#  'tidak apaapa <EOS>',
#  'kucoba kembalikan itu kejahatan <EOS>',
#  'tidakkah kau paham <EOS>',
#  'semakin kau menarik perhatian <EOS>',
#  'orang tidak mengenalimu <EOS>',
#  'apa rahasiamu <EOS>',
#  'apa harus ada rahasia <EOS>',
#  'sesuatu untuk disembunyikan <EOS>',
#  'itu pekerjaanmu <EOS>',
#  'apa yang kau lihat dalam keseharianmu <EOS>',
#  'itulah kenapa kau takkan pernah paham <EOS>',
#  'sesuatu untuk disembunyikan <EOS>',
#  'aku tak punya apapun untuk kau lihat <EOS>',
#  'everyagent aka orang noob yang pro <EOS>',
#  'salam dari anak tkj smkn  jakarta <EOS>',
#  'everyagent aka orang noob yang pro <EOS>',
#  'salam dari anak tkj smkn  jakarta <EOS>',
#  'wa  or pm me <EOS>',
#  'aku menyerah dalam bertarung <EOS>',
#  'biarlah ada akhir <EOS>',
#  'sebuah privasi <EOS>',
#  'sudut tersembunyi untukku <EOS>',
#  'aku ingin dilupakan bahkan oleh tuhan <EOS>',
#  'paracelsus <EOS>',
#  'bakar hidrogen facelvega <EOS>',
#  'inspirasi facelvega <EOS>',
#  'kau beruntung semalam <EOS>',
#  'tentu saja kau sendiri <EOS>',
#  'aku adalah jendela terbuka <EOS>',
#  'melebihi tak terhingga <EOS>',
#  'dunia baru di pergelangan tanganmu <EOS>',
#  'tidak diketahui  kesalahan <EOS>',
#  'tahun wakil petugas <EOS>',
#  'tahun detektif kelas satu <EOS>',
#  'ini soal putraku <EOS>',
#  'tahun pialang asuransi <EOS>',
#  'dia belum balas panggilanku <EOS>',
#  'ini bukan sifatnya <EOS>',
#  'kau tahu yang terjadi <EOS>',
#  'terdeteksi di ether satu jam yang lalu <EOS>',
#  'yakin mau lihat <EOS>',
#  'ya <EOS>',
#  ...]

# %% [markdown]
# ### Konversi ke NUMERIK dan replace OUT

# %%
trn_question = []
for idx,qst in enumerate(question):
    phr = qst.split()
    for idx, i in enumerate(phr):
        try:
            phr[idx] = questionswords2int[i]
        except:
            phr[idx] = questionswords2int['<OUT>']
    trn_question.append(phr)
    
trn_answer = []
for idx,answ in enumerate(answer):
    phr = answ.split()
    for idx, i in enumerate(phr):
        try:
            phr[idx] = answerswords2int[i]
        except:
            phr[idx] = answerswords2int['<OUT>']
    trn_answer.append(phr)

# %% [markdown]
# ### Check

# %%
for i in range(10):
    print(answer[i],trn_answer[i])
# Out:
# salam dari anak tkj smkn  jakarta <EOS> [4, 5, 6, 10032, 10032, 10032, 10031]
# wa  or pm me <EOS> [7, 8, 9, 10, 10031]
# aku menyerah dalam bertarung <EOS> [11, 12, 13, 14, 10031]
# biarlah ada akhir <EOS> [15, 16, 17, 10031]
# sebuah privasi <EOS> [18, 19, 10031]
# sudut tersembunyi untukku <EOS> [20, 21, 22, 10031]
# aku ingin dilupakan bahkan oleh tuhan <EOS> [11, 23, 24, 25, 26, 27, 10031]
# paracelsus <EOS> [10032, 10031]
# bakar hidrogen facelvega <EOS> [28, 10032, 10032, 10031]
# inspirasi facelvega <EOS> [29, 10032, 10031]

# %% [markdown]
# ### Sortir dari panjang yang paling sedikit

# %%
maxlen=25

sort_question_n = []
sort_answer_n = []
for i in range(1,maxlen):
    for idx, qst in enumerate(trn_question):
        if len(qst) == i:
            sort_question_n.append(trn_question[idx])
            sort_answer_n.append(trn_answer[idx])

# %%
alf = sort_question_n[-1]

# %%
sort_answer_n
# Out:
# [[29, 30, 12739, 12738, 12738],
#  [12, 74, 77, 12738, 12738],
#  [78, 79, 80, 12738, 12738],
#  [85, 12738, 12738],
#  [86, 87, 12738, 12738],
#  [162, 163, 12738, 12738],
#  [179, 106, 67, 180, 2, 181, 12738, 12738],
#  [82, 83, 12738, 12738],
#  [62, 185, 186, 187, 12738, 12738],
#  [180, 32, 12738, 12738],
#  [86, 87, 12738, 12738],
#  [215, 199, 175, 1, 101, 12738, 12738],
#  [228, 103, 229, 230, 12738, 12738],
#  [241, 81, 57, 80, 12738, 12738],
#  [256, 257, 12738, 12738],
#  [261, 12738, 12738],
#  [12, 107, 12738, 12738],
#  [12, 825, 48, 90, 12738, 12738],
#  [48, 17, 365, 366, 12738, 12738],
#  [106, 42, 98, 127, 12738, 12738],
#  [48, 12738, 12738],
#  [32, 361, 369, 12738, 12738],
#  [373, 259, 12738, 12738],
#  [387, 388, 389, 106, 390, 12738, 12738],
#  [32, 395, 12738, 12738],
#  [162, 163, 12738, 12738],
#  [206, 244, 36, 12, 12738, 12738],
#  [86, 87, 12738, 12738],
#  [110, 403, 21, 136, 404, 12738, 12738],
#  [62, 330, 186, 416, 12738, 12738],
#  [128, 12738, 12738],
#  [206, 244, 36, 12, 12738, 12738],
#  [86, 87, 12738, 12738],
#  [14, 444, 12739, 376, 12738, 12738],
#  [493, 494, 12738, 12738],
#  [501, 504, 90, 36, 505, 12738, 12738],
#  [2, 533, 2, 44, 24, 466, 12738, 12738],
#  [12, 48, 398, 12738, 12738],
#  [537, 538, 12738, 12738],
#  [561, 555, 32, 562, 165, 12738, 12738],
#  [405, 344, 62, 355, 408, 12738, 12738],
#  [48, 49, 50, 12738, 12738],
#  [270, 2, 72, 12738, 12738],
#  [12, 90, 592, 593, 12738, 12738],
#  [129, 596, 12739, 12738, 12738],
#  [599, 194, 304, 101, 12738, 12738],
#  [614, 615, 12738, 12738],
#  [101, 36, 12738, 12738],
#  [75, 186, 639, 230, 12738, 12738],
#  [259, 12738, 12738],
#  [12, 98, 12739, 2, 642, 12738, 12738],
#  [176, 62, 48, 487, 12738, 12738],
#  [373, 12738, 12738],
#  [51, 661, 662, 663, 12738, 12738],
#  [12, 67, 165, 101, 12738, 12738],
#  [2, 238, 560, 12738, 12738],
#  [572, 326, 12738, 12738],
#  [62, 512, 716, 175, 717, 12738, 12738],
#  [17, 165, 12739, 709, 718, 56, 12739, 12738, 12738],
#  [106, 225, 734, 388, 735, 12738, 12738],
#  [106, 742, 12739, 12738, 12738],
#  [201, 32, 728, 12738, 12738],
#  [114, 646, 592, 12739, 12738, 12738],
#  [12, 801, 48, 345, 12738, 12738],
#  [48, 807, 808, 809, 12738, 12738],
#  [466, 814, 12738, 12738],
#  [838, 839, 12738, 12738],
#  [76, 101, 62, 12738, 12738],
#  [48, 12738, 12738],
#  [12, 42, 74, 853, 101, 854, 12738, 12738],
#  [176, 129, 165, 12738, 12738],
#  [855, 12738, 12738],
#  [193, 12738, 12738],
#  [259, 856, 326, 12738, 12738],
#  [259, 12738, 12738],
#  [259, 12738, 12738],
#  [259, 12738, 12738],
#  [12, 857, 12738, 12738],
#  [860, 861, 12738, 12738],
#  [59, 12739, 12738, 12738],
#  [12, 42, 235, 881, 387, 659, 12738, 12738],
#  [594, 386, 125, 12738, 12738],
#  [646, 512, 2, 646, 75, 12738, 12738],
#  [176, 32, 126, 57, 262, 12738, 12738],
#  [212, 213, 12738, 12738],
#  [256, 257, 12738, 12738],
#  [887, 32, 12739, 12738, 12738],
#  [776, 777, 12738, 12738],
#  [176, 32, 126, 101, 12738, 12738],
#  [176, 32, 126, 57, 12738, 12738],
#  [12, 67, 954, 12739, 32, 955, 12738, 12738],
#  [919, 920, 42, 68, 12738, 12738],
#  [201, 361, 956, 12738, 12738],
#  [76, 12738, 12738],
#  [62, 919, 920, 101, 958, 12738, 12738],
#  [101, 44, 966, 12738, 12738],
#  [972, 327, 726, 973, 128, 12738, 12738],
#  [29, 30, 12739, 12738, 12738],
#  [12, 74, 77, 12738, 12738],
#  [78, 79, 80, 12738, 12738],
#  [85, 12738, 12738],
#  [86, 87, 12738, 12738],
#  [162, 163, 12738, 12738],
#  [179, 106, 67, 180, 2, 181, 12738, 12738],
#  [82, 83, 12738, 12738],
#  [62, 185, 186, 187, 12738, 12738],
#  [180, 32, 12738, 12738],
#  [86, 87, 12738, 12738],
#  [215, 199, 175, 1, 101, 12738, 12738],
#  [228, 103, 229, 230, 12738, 12738],
#  [241, 81, 57, 80, 12738, 12738],
#  [256, 257, 12738, 12738],
#  [261, 12738, 12738],
#  [12, 107, 12738, 12738],
#  [12, 825, 48, 90, 12738, 12738],
#  [48, 17, 365, 366, 12738, 12738],
#  [106, 42, 98, 127, 12738, 12738],
#  [48, 12738, 12738],
#  [32, 361, 369, 12738, 12738],
#  [373, 259, 12738, 12738],
#  [387, 388, 389, 106, 390, 12738, 12738],
#  [32, 395, 12738, 12738],
#  [162, 163, 12738, 12738],
#  [206, 244, 36, 12, 12738, 12738],
#  [86, 87, 12738, 12738],
#  [110, 403, 21, 136, 404, 12738, 12738],
#  [62, 330, 186, 416, 12738, 12738],
#  [128, 12738, 12738],
#  [206, 244, 36, 12, 12738, 12738],
#  [86, 87, 12738, 12738],
#  [14, 444, 12739, 376, 12738, 12738],
#  [493, 494, 12738, 12738],
#  [501, 504, 90, 36, 505, 12738, 12738],
#  [2, 533, 2, 44, 24, 466, 12738, 12738],
#  [12, 48, 398, 12738, 12738],
#  [537, 538, 12738, 12738],
#  [561, 555, 32, 562, 165, 12738, 12738],
#  [405, 344, 62, 355, 408, 12738, 12738],
#  [48, 49, 50, 12738, 12738],
#  [270, 2, 72, 12738, 12738],
#  [12, 90, 592, 593, 12738, 12738],
#  [129, 596, 12739, 12738, 12738],
#  [599, 194, 304, 101, 12738, 12738],
#  [614, 615, 12738, 12738],
#  [101, 36, 12738, 12738],
#  [75, 186, 639, 230, 12738, 12738],
#  [259, 12738, 12738],
#  [12, 98, 12739, 2, 642, 12738, 12738],
#  [176, 62, 48, 487, 12738, 12738],
#  [373, 12738, 12738],
#  [51, 661, 662, 663, 12738, 12738],
#  [12, 67, 165, 101, 12738, 12738],
#  [2, 238, 560, 12738, 12738],
#  [572, 326, 12738, 12738],
#  [62, 512, 716, 175, 717, 12738, 12738],
#  [17, 165, 12739, 709, 718, 56, 12739, 12738, 12738],
#  [106, 225, 734, 388, 735, 12738, 12738],
#  [106, 742, 12739, 12738, 12738],
#  [201, 32, 728, 12738, 12738],
#  [114, 646, 592, 12739, 12738, 12738],
#  [12, 801, 48, 345, 12738, 12738],
#  [48, 807, 808, 809, 12738, 12738],
#  [466, 814, 12738, 12738],
#  [838, 839, 12738, 12738],
#  [76, 101, 62, 12738, 12738],
#  [48, 12738, 12738],
#  [12, 42, 74, 853, 101, 854, 12738, 12738],
#  [176, 129, 165, 12738, 12738],
#  [855, 12738, 12738],
#  [193, 12738, 12738],
#  [259, 856, 326, 12738, 12738],
#  [259, 12738, 12738],
#  [259, 12738, 12738],
#  [259, 12738, 12738],
#  [12, 857, 12738, 12738],
#  [860, 861, 12738, 12738],
#  [59, 12739, 12738, 12738],
#  [12, 42, 235, 881, 387, 659, 12738, 12738],
#  [594, 386, 125, 12738, 12738],
#  [646, 512, 2, 646, 75, 12738, 12738],
#  [176, 32, 126, 57, 262, 12738, 12738],
#  [212, 213, 12738, 12738],
#  [256, 257, 12738, 12738],
#  [887, 32, 12739, 12738, 12738],
#  [776, 777, 12738, 12738],
#  [176, 32, 126, 101, 12738, 12738],
#  [176, 32, 126, 57, 12738, 12738],
#  [12, 67, 954, 12739, 32, 955, 12738, 12738],
#  [919, 920, 42, 68, 12738, 12738],
#  [201, 361, 956, 12738, 12738],
#  [76, 12738, 12738],
#  [62, 919, 920, 101, 958, 12738, 12738],
#  [101, 44, 966, 12738, 12738],
#  [972, 327, 726, 973, 128, 12738, 12738],
#  [1001, 1001, 12738, 12738],
#  [1013, 57, 254, 1, 876, 1014, 12738, 12738],
#  [17, 729, 997, 428, 12738, 12738],
#  [400, 1031, 239, 12738, 12738],
#  [1035, 288, 12739, 12738, 12738],
#  [6, 1048, 12738, 12738],
#  [1070, 1071, 12738, 12738],
#  [1073, 997, 1074, 12738, 12738],
#  [165, 2, 24, 1113, 1114, 1115, 12738, 12738],
#  [1089, 135, 1119, 12738, 12738],
#  [1124, 32, 1125, 12738, 12738],
#  [1116, 1132, 527, 12738, 12738],
#  [129, 715, 957, 12738, 12738],
#  [217, 803, 1156, 12738, 12738],
#  [12, 282, 1157, 299, 12738, 12738],
#  [1191, 36, 12738, 12738],
#  [1000, 282, 1197, 587, 5, 12739, 12738, 12738],
#  [62, 515, 242, 1207, 12738, 12738],
#  [1211, 12739, 12739, 12739, 12738, 12738],
#  [1094, 1095, 392, 726, 718, 56, 667, 1089, 12738, 12738],
#  [1104, 1235, 150, 1103, 124, 1236, 1149, 12738, 12738],
#  [1012, 107, 12738, 12738],
#  [12739, 12738, 12738],
#  [274, 32, 562, 651, 549, 12, 12738, 12738],
#  [101, 1089, 12738, 12738],
#  [1012, 107, 12738, 12738],
#  [1113, 1002, 36, 1149, 12738, 12738],
#  [1246, 129, 814, 12738, 12738],
#  [101, 686, 106, 12738, 12738],
#  [887, 12739, 12738, 12738],
#  [131, 5, 1104, 101, 12738, 12738],
#  [400, 1264, 37, 12738, 12738],
#  [1141, 114, 57, 799, 12738, 12738],
#  [451, 1089, 1294, 45, 247, 57, 12738, 12738],
#  [106, 48, 939, 50, 12738, 12738],
#  [165, 1113, 255, 255, 36, 12738, 12738],
#  [832, 12, 1306, 12738, 12738],
#  [1123, 425, 12738, 12738],
#  [372, 1123, 12738, 12738],
#  [1089, 1312, 32, 1311, 12738, 12738],
#  [150, 515, 103, 968, 12738, 12738],
#  [1, 1163, 12738, 12738],
#  [12739, 12738, 12738],
#  [354, 1324, 12738, 12738],
#  [32, 180, 12738, 12738],
#  [372, 12738, 12738],
#  [884, 884, 12738, 12738],
#  [391, 48, 469, 12738, 12738],
#  [56, 1336, 150, 1337, 1338, 12738, 12738],
#  [169, 150, 1343, 38, 1344, 12738, 12738],
#  [1, 1315, 14, 1163, 12738, 12738],
#  [1331, 106, 1353, 12738, 12738],
#  [1124, 32, 1125, 12738, 12738],
#  [12, 48, 90, 1274, 1089, 12738, 12738],
#  [1084, 473, 1266, 12738, 12738],
#  [832, 267, 12739, 12738, 12738],
#  [125, 1373, 12, 12738, 12738],
#  [76, 28, 76, 28, 12738, 12738],
#  [1090, 1374, 12738, 12738],
#  [1375, 12738, 12738],
#  [1375, 12738, 12738],
#  [1012, 325, 1375, 12738, 12738],
#  [165, 361, 87, 12738, 12738],
#  [1066, 12, 1316, 48, 90, 1376, 12738, 12738],
#  [386, 1110, 1378, 12738, 12738],
#  [12, 67, 12738, 12738],
#  [812, 12738, 12738],
#  [274, 32, 864, 222, 282, 124, 12738, 12738],
#  [372, 1394, 1395, 12738, 12738],
#  [1339, 1014, 330, 1299, 12738, 12738],
#  [1212, 32, 1247, 12738, 12738],
#  [1348, 469, 934, 12738, 12738],
#  [180, 101, 12738, 12738],
#  [267, 1403, 5, 995, 2, 333, 12738, 12738],
#  [267, 1369, 1406, 45, 1094, 1095, 12738, 12738],
#  [1411, 453, 281, 57, 62, 1042, 106, 231, 12738, 12738],
#  [274, 62, 24, 330, 12738, 12738],
#  [267, 282, 667, 1381, 57, 12738, 12738],
#  [307, 12, 282, 1415, 37, 12738, 12738],
#  [1163, 12738, 12738],
#  [169, 129, 318, 12738, 12738],
#  [1137, 12738, 12738],
#  [1137, 165, 1113, 1002, 36, 12738, 12738],
#  [369, 1172, 103, 1163, 87, 12738, 12738],
#  [90, 32, 1421, 330, 160, 101, 12738, 12738],
#  [215, 36, 12738, 12738],
#  [1432, 106, 66, 1433, 12738, 12738],
#  [12739, 12739, 1130, 129, 165, 12738, 12738],
#  [367, 12739, 98, 330, 1149, 12738, 12738],
#  [222, 282, 1014, 12738, 12738],
#  [1442, 66, 215, 1163, 12738, 12738],
#  [12, 48, 15, 14, 1076, 57, 12738, 12738],
#  [165, 2, 32, 1174, 12738, 12738],
#  [1130, 1152, 247, 12738, 12738],
#  [12, 48, 282, 107, 940, 12738, 12738],
#  [12, 231, 12738, 12738],
#  [12, 436, 644, 12738, 12738],
#  [1115, 12738, 12738],
#  [1330, 45, 1449, 12738, 12738],
#  [274, 12, 1450, 12738, 12738],
#  [12, 282, 1441, 1212, 1127, 1452, 12738, 12738],
#  [48, 282, 1454, 12738, 12738],
#  [48, 751, 239, 12738, 12738],
#  [107, 12738, 12738],
#  [1018, 222, 12738, 12738],
#  [381, 12738, 12738],
#  [1468, 38, 12, 12738, 12738],
#  [267, 282, 1469, 957, 12738, 12738],
#  [158, 1415, 57, 12738, 12738],
#  [1012, 453, 12738, 12738],
#  [1012, 1466, 222, 12738, 12738],
#  [1339, 889, 12738, 12738],
#  [103, 1479, 1480, 12738, 12738],
#  [32, 182, 45, 409, 12738, 12738],
#  [160, 994, 12738, 12738],
#  [1362, 165, 101, 1242, 12738, 12738],
#  [1012, 107, 12738, 12738],
#  [233, 12738, 12738],
#  [1501, 222, 129, 15, 12738, 12738],
#  [165, 32, 255, 255, 36, 12738, 12738],
#  [12, 751, 12738, 12738],
#  [106, 628, 12738, 12738],
#  [12, 282, 791, 235, 12738, 12738],
#  [125, 601, 1, 230, 12738, 12738],
#  [176, 32, 1507, 12738, 12738],
#  [165, 32, 168, 24, 1118, 267, 12738, 12738],
#  [101, 1524, 212, 36, 12738, 12738],
#  [319, 12738, 12738],
#  [176, 62, 1311, 12738, 12738],
#  [701, 513, 1513, 12739, 1004, 12738, 12738],
#  [986, 27, 987, 12738, 12738],
#  [607, 1536, 12738, 12738],
#  [198, 1537, 1538, 12738, 12738],
#  [1540, 1541, 12738, 12738],
#  [1012, 12738, 12738],
#  [868, 508, 12738, 12738],
#  [1543, 1544, 1, 57, 12738, 12738],
#  [772, 12738, 12738],
#  [1551, 1552, 12738, 12738],
#  [150, 1561, 1562, 1563, 12738, 12738],
#  [734, 1566, 110, 12738, 12738],
#  [1579, 57, 1580, 42, 90, 1046, 12738, 12738],
#  [1596, 12738, 12738],
#  [1597, 12738, 12738],
#  [12739, 12738, 12738],
#  [1598, 12738, 12738],
#  [12739, 12738, 12738],
#  [12739, 12738, 12738],
#  [12739, 12738, 12738],
#  [12739, 12738, 12738],
#  [12739, 12738, 12738],
#  [12739, 12738, 12738],
#  [858, 288, 1, 1398, 12738, 12738],
#  [76, 660, 12738, 12738],
#  [1593, 186, 306, 106, 107, 12738, 12738],
#  [186, 412, 1612, 1529, 12738, 12738],
#  [57, 42, 253, 210, 1149, 12738, 12738],
#  [57, 42, 1638, 125, 640, 12738, 12738],
#  [76, 28, 12738, 12738],
#  [76, 110, 12738, 12738],
#  [475, 2, 106, 159, 1666, 12738, 12738],
#  [1548, 12738, 12738],
#  [1559, 12739, 281, 57, 12738, 12738],
#  [106, 33, 284, 1149, 12738, 12738],
#  [101, 633, 12738, 12738],
#  [1018, 1012, 12738, 12738],
#  [868, 1686, 12738, 12738],
#  [214, 12738, 12738],
#  [868, 1012, 12738, 12738],
#  [868, 1686, 125, 812, 12738, 12738],
#  [1273, 12, 1012, 12738, 12738],
#  [12, 90, 1539, 12738, 12738],
#  [1700, 1676, 57, 12738, 12738],
#  [191, 1586, 1587, 129, 637, 12738, 12738],
#  [1586, 12738, 12738],
#  [201, 1495, 129, 1710, 1623, 12738, 12738],
#  [180, 1711, 12738, 12738],
#  [12739, 12738, 12738],
#  [110, 12738, 12738],
#  [1543, 1553, 2, 124, 12738, 12738],
#  [1548, 12738, 12738],
#  [12, 48, 165, 12738, 12738],
#  [637, 1701, 1748, 12738, 12738],
#  [12, 1749, 12738, 12738],
#  [165, 1752, 45, 766, 929, 12738, 12738],
#  [572, 1740, 1553, 1738, 1313, 12738, 12738],
#  [165, 12738, 12738],
#  [1301, 325, 45, 1704, 451, 1764, 51, 12738, 12738],
#  [1739, 1062, 1562, 1563, 12738, 12738],
#  [5, 1546, 106, 150, 12738, 12738],
#  [63, 12738, 12738],
#  [426, 106, 400, 12739, 376, 12738, 12738],
#  [32, 307, 12739, 1784, 12738, 12738],
#  [1710, 222, 282, 12739, 150, 1786, 12738, 12738],
#  [453, 1793, 1794, 12738, 12738],
#  [1, 186, 1146, 12739, 12739, 12738, 12738],
#  [1806, 513, 1660, 1659, 12738, 12738],
#  [1811, 1812, 12738, 12738],
#  [180, 1711, 1553, 12738, 12738],
#  [85, 12738, 12738],
#  [85, 12738, 12738],
#  [1820, 12738, 12738],
#  [1738, 185, 12738, 12738],
#  [400, 1700, 1676, 12738, 12738],
#  [1686, 186, 1262, 1609, 12738, 12738],
#  [1823, 12738, 12738],
#  [1686, 12738, 12738],
#  [1686, 12738, 12738],
#  [1012, 12738, 12738],
#  [107, 186, 1821, 1735, 12738, 12738],
#  [1686, 12738, 12738],
#  [1012, 814, 12738, 12738],
#  [1806, 1660, 1659, 12738, 12738],
#  [233, 267, 66, 655, 437, 12738, 12738],
#  [2, 1243, 562, 1745, 12738, 12738],
#  [176, 106, 400, 1620, 1642, 1529, 12738, 12738],
#  [372, 12, 45, 409, 887, 12, 1, 1704, 12738, 12738],
#  [48, 110, 12738, 12738],
#  [1730, 12738, 12738],
#  [1860, 1831, 1832, 101, 12738, 12738],
#  [274, 62, 12739, 896, 12738, 12738],
#  [1559, 12738, 12738],
#  [62, 1077, 284, 12738, 12738],
#  [1539, 1596, 12738, 12738],
#  [32, 282, 171, 12739, 1559, 12738, 12738],
#  [1566, 12738, 12738],
#  [755, 1539, 12738, 12738],
#  [868, 1628, 12738, 12738],
#  [12, 512, 513, 689, 1885, 101, 12738, 12738],
#  [265, 88, 1886, 12738, 12738],
#  [106, 400, 1337, 186, 246, 1733, 12738, 12738],
#  [165, 2, 32, 126, 1644, 12738, 12738],
#  [1553, 1754, 12738, 12738],
#  [193, 12738, 12738],
#  [644, 110, 12738, 12738],
#  [1566, 106, 12739, 45, 766, 267, 12738, 12738],
#  [1539, 12738, 12738],
#  [1012, 868, 508, 12738, 12738],
#  [1301, 362, 1732, 1, 2, 124, 12738, 12738],
#  [1902, 32, 1903, 12739, 12738, 12738],
#  [12, 392, 584, 12738, 12738],
#  [537, 538, 12738, 12738],
#  [176, 1874, 45, 409, 12738, 12738],
#  [12, 1559, 12739, 12738, 12738],
#  [400, 1943, 57, 934, 12738, 12738],
#  [57, 62, 12738, 12738],
#  [537, 538, 12738, 12738],
#  [110, 12738, 12738],
#  [1905, 2, 32, 90, 12738, 12738],
#  [406, 2, 230, 12738, 12738],
#  [1644, 12738, 12738],
#  [265, 898, 150, 915, 45, 500, 12738, 12738],
#  [62, 1351, 651, 12738, 12738],
#  [1546, 801, 1739, 106, 12738, 12738],
#  [12, 231, 12738, 12738],
#  [12, 24, 32, 362, 1544, 1531, 1533, 12738, 12738],
#  [915, 855, 12738, 12738],
#  [1769, 57, 1985, 12738, 12738],
#  [12739, 12738, 12738],
#  [12, 98, 12738, 12738],
#  [12739, 12738, 12738],
#  [12739, 12738, 12738],
#  [12, 24, 32, 1419, 777, 12738, 12738],
#  [32, 150, 1989, 156, 1683, 12738, 12738],
#  [1559, 12738, 12738],
#  [1700, 1991, 12738, 12738],
#  [2009, 1048, 2010, 2011, 12738, 12738],
#  [48, 12738, 12738],
#  [1686, 12738, 12738],
#  [868, 508, 12738, 12738],
#  [529, 274, 386, 12738, 12738],
#  [868, 508, 12738, 12738],
#  [868, 508, 12738, 12738],
#  [12739, 1577, 1578, 12738, 12738],
#  [2013, 32, 825, 1243, 12738, 12738],
#  [1012, 158, 107, 12738, 12738],
#  [106, 1291, 12738, 12738],
#  [29, 30, 12739, 12738, 12738],
#  [12, 74, 77, 12738, 12738],
#  [78, 79, 80, 12738, 12738],
#  [85, 12738, 12738],
#  [86, 87, 12738, 12738],
#  [162, 163, 12738, 12738],
#  [179, 106, 67, 180, 2, 181, 12738, 12738],
#  [82, 83, 12738, 12738],
#  [62, 185, 186, 187, 12738, 12738],
#  [180, 32, 12738, 12738],
#  [86, 87, 12738, 12738],
#  [215, 199, 175, 1, 101, 12738, 12738],
#  [228, 103, 229, 230, 12738, 12738],
#  [241, 81, 57, 80, 12738, 12738],
#  [256, 257, 12738, 12738],
#  [261, 12738, 12738],
#  [12, 107, 12738, 12738],
#  [12, 825, 48, 90, 12738, 12738],
#  [48, 17, 365, 366, 12738, 12738],
#  [106, 42, 98, 127, 12738, 12738],
#  [48, 12738, 12738],
#  [32, 361, 369, 12738, 12738],
#  [373, 259, 12738, 12738],
#  [387, 388, 389, 106, 390, 12738, 12738],
#  [32, 395, 12738, 12738],
#  [162, 163, 12738, 12738],
#  [206, 244, 36, 12, 12738, 12738],
#  [86, 87, 12738, 12738],
#  [110, 403, 21, 136, 404, 12738, 12738],
#  [62, 330, 186, 416, 12738, 12738],
#  [128, 12738, 12738],
#  [206, 244, 36, 12, 12738, 12738],
#  [86, 87, 12738, 12738],
#  [14, 444, 12739, 376, 12738, 12738],
#  [493, 494, 12738, 12738],
#  [501, 504, 90, 36, 505, 12738, 12738],
#  [2, 533, 2, 44, 24, 466, 12738, 12738],
#  [12, 48, 398, 12738, 12738],
#  [537, 538, 12738, 12738],
#  [561, 555, 32, 562, 165, 12738, 12738],
#  [405, 344, 62, 355, 408, 12738, 12738],
#  [48, 49, 50, 12738, 12738],
#  [270, 2, 72, 12738, 12738],
#  [12, 90, 592, 593, 12738, 12738],
#  [129, 596, 12739, 12738, 12738],
#  [599, 194, 304, 101, 12738, 12738],
#  [614, 615, 12738, 12738],
#  [101, 36, 12738, 12738],
#  [75, 186, 639, 230, 12738, 12738],
#  [259, 12738, 12738],
#  [12, 98, 12739, 2, 642, 12738, 12738],
#  [176, 62, 48, 487, 12738, 12738],
#  [373, 12738, 12738],
#  [51, 661, 662, 663, 12738, 12738],
#  [12, 67, 165, 101, 12738, 12738],
#  [2, 238, 560, 12738, 12738],
#  [572, 326, 12738, 12738],
#  [62, 512, 716, 175, 717, 12738, 12738],
#  [17, 165, 12739, 709, 718, 56, 12739, 12738, 12738],
#  [106, 225, 734, 388, 735, 12738, 12738],
#  [106, 742, 12739, 12738, 12738],
#  [201, 32, 728, 12738, 12738],
#  [114, 646, 592, 12739, 12738, 12738],
#  [12, 801, 48, 345, 12738, 12738],
#  [48, 807, 808, 809, 12738, 12738],
#  [466, 814, 12738, 12738],
#  [838, 839, 12738, 12738],
#  [76, 101, 62, 12738, 12738],
#  [48, 12738, 12738],
#  [12, 42, 74, 853, 101, 854, 12738, 12738],
#  [176, 129, 165, 12738, 12738],
#  [855, 12738, 12738],
#  [193, 12738, 12738],
#  [259, 856, 326, 12738, 12738],
#  [259, 12738, 12738],
#  [259, 12738, 12738],
#  [259, 12738, 12738],
#  [12, 857, 12738, 12738],
#  [860, 861, 12738, 12738],
#  [59, 12739, 12738, 12738],
#  [12, 42, 235, 881, 387, 659, 12738, 12738],
#  [594, 386, 125, 12738, 12738],
#  [646, 512, 2, 646, 75, 12738, 12738],
#  [176, 32, 126, 57, 262, 12738, 12738],
#  [212, 213, 12738, 12738],
#  [256, 257, 12738, 12738],
#  [887, 32, 12739, 12738, 12738],
#  [776, 777, 12738, 12738],
#  [176, 32, 126, 101, 12738, 12738],
#  [176, 32, 126, 57, 12738, 12738],
#  [12, 67, 954, 12739, 32, 955, 12738, 12738],
#  [919, 920, 42, 68, 12738, 12738],
#  [201, 361, 956, 12738, 12738],
#  [76, 12738, 12738],
#  [62, 919, 920, 101, 958, 12738, 12738],
#  [101, 44, 966, 12738, 12738],
#  [972, 327, 726, 973, 128, 12738, 12738],
#  [607, 1536, 12738, 12738],
#  [198, 1537, 1538, 12738, 12738],
#  [1540, 1541, 12738, 12738],
#  [1012, 12738, 12738],
#  [868, 508, 12738, 12738],
#  [1543, 1544, 1, 57, 12738, 12738],
#  [772, 12738, 12738],
#  [1551, 1552, 12738, 12738],
#  [150, 1561, 1562, 1563, 12738, 12738],
#  [734, 1566, 110, 12738, 12738],
#  [1579, 57, 1580, 42, 90, 1046, 12738, 12738],
#  [1596, 12738, 12738],
#  [1597, 12738, 12738],
#  [12739, 12738, 12738],
#  [1598, 12738, 12738],
#  [12739, 12738, 12738],
#  [12739, 12738, 12738],
#  [12739, 12738, 12738],
#  [12739, 12738, 12738],
#  [12739, 12738, 12738],
#  [12739, 12738, 12738],
#  [858, 288, 1, 1398, 12738, 12738],
#  [76, 660, 12738, 12738],
#  [1593, 186, 306, 106, 107, 12738, 12738],
#  [186, 412, 1612, 1529, 12738, 12738],
#  [57, 42, 253, 210, 1149, 12738, 12738],
#  [57, 42, 1638, 125, 640, 12738, 12738],
#  [76, 28, 12738, 12738],
#  [76, 110, 12738, 12738],
#  [475, 2, 106, 159, 1666, 12738, 12738],
#  [1548, 12738, 12738],
#  [1559, 12739, 281, 57, 12738, 12738],
#  [106, 33, 284, 1149, 12738, 12738],
#  [101, 633, 12738, 12738],
#  [1018, 1012, 12738, 12738],
#  [868, 1686, 12738, 12738],
#  [214, 12738, 12738],
#  [868, 1012, 12738, 12738],
#  [868, 1686, 125, 812, 12738, 12738],
#  [1273, 12, 1012, 12738, 12738],
#  [12, 90, 1539, 12738, 12738],
#  [1700, 1676, 57, 12738, 12738],
#  [191, 1586, 1587, 129, 637, 12738, 12738],
#  [1586, 12738, 12738],
#  [201, 1495, 129, 1710, 1623, 12738, 12738],
#  [180, 1711, 12738, 12738],
#  [12739, 12738, 12738],
#  [110, 12738, 12738],
#  [1543, 1553, 2, 124, 12738, 12738],
#  [1548, 12738, 12738],
#  [12, 48, 165, 12738, 12738],
#  [637, 1701, 1748, 12738, 12738],
#  [12, 1749, 12738, 12738],
#  [165, 1752, 45, 766, 929, 12738, 12738],
#  [572, 1740, 1553, 1738, 1313, 12738, 12738],
#  [165, 12738, 12738],
#  [1301, 325, 45, 1704, 451, 1764, 51, 12738, 12738],
#  [1739, 1062, 1562, 1563, 12738, 12738],
#  [5, 1546, 106, 150, 12738, 12738],
#  [63, 12738, 12738],
#  [426, 106, 400, 12739, 376, 12738, 12738],
#  [32, 307, 12739, 1784, 12738, 12738],
#  [1710, 222, 282, 12739, 150, 1786, 12738, 12738],
#  [453, 1793, 1794, 12738, 12738],
#  [1, 186, 1146, 12739, 12739, 12738, 12738],
#  [1806, 513, 1660, 1659, 12738, 12738],
#  [1811, 1812, 12738, 12738],
#  [180, 1711, 1553, 12738, 12738],
#  [85, 12738, 12738],
#  [85, 12738, 12738],
#  [1820, 12738, 12738],
#  [1738, 185, 12738, 12738],
#  [400, 1700, 1676, 12738, 12738],
#  [1686, 186, 1262, 1609, 12738, 12738],
#  [1823, 12738, 12738],
#  [1686, 12738, 12738],
#  [1686, 12738, 12738],
#  [1012, 12738, 12738],
#  [107, 186, 1821, 1735, 12738, 12738],
#  [1686, 12738, 12738],
#  [1012, 814, 12738, 12738],
#  [1806, 1660, 1659, 12738, 12738],
#  [233, 267, 66, 655, 437, 12738, 12738],
#  [2, 1243, 562, 1745, 12738, 12738],
#  [176, 106, 400, 1620, 1642, 1529, 12738, 12738],
#  [372, 12, 45, 409, 887, 12, 1, 1704, 12738, 12738],
#  [48, 110, 12738, 12738],
#  [1730, 12738, 12738],
#  [1860, 1831, 1832, 101, 12738, 12738],
#  [274, 62, 12739, 896, 12738, 12738],
#  [1559, 12738, 12738],
#  [62, 1077, 284, 12738, 12738],
#  [1539, 1596, 12738, 12738],
#  [32, 282, 171, 12739, 1559, 12738, 12738],
#  [1566, 12738, 12738],
#  [755, 1539, 12738, 12738],
#  [868, 1628, 12738, 12738],
#  [12, 512, 513, 689, 1885, 101, 12738, 12738],
#  [265, 88, 1886, 12738, 12738],
#  [106, 400, 1337, 186, 246, 1733, 12738, 12738],
#  [165, 2, 32, 126, 1644, 12738, 12738],
#  [1553, 1754, 12738, 12738],
#  [193, 12738, 12738],
#  [644, 110, 12738, 12738],
#  [1566, 106, 12739, 45, 766, 267, 12738, 12738],
#  [1539, 12738, 12738],
#  [1012, 868, 508, 12738, 12738],
#  [1301, 362, 1732, 1, 2, 124, 12738, 12738],
#  [1902, 32, 1903, 12739, 12738, 12738],
#  [12, 392, 584, 12738, 12738],
#  [537, 538, 12738, 12738],
#  [176, 1874, 45, 409, 12738, 12738],
#  [12, 1559, 12739, 12738, 12738],
#  [400, 1943, 57, 934, 12738, 12738],
#  [57, 62, 12738, 12738],
#  [537, 538, 12738, 12738],
#  [110, 12738, 12738],
#  [1905, 2, 32, 90, 12738, 12738],
#  [406, 2, 230, 12738, 12738],
#  [1644, 12738, 12738],
#  [265, 898, 150, 915, 45, 500, 12738, 12738],
#  [62, 1351, 651, 12738, 12738],
#  [1546, 801, 1739, 106, 12738, 12738],
#  [12, 231, 12738, 12738],
#  [12, 24, 32, 362, 1544, 1531, 1533, 12738, 12738],
#  [915, 855, 12738, 12738],
#  [1769, 57, 1985, 12738, 12738],
#  [12739, 12738, 12738],
#  [12, 98, 12738, 12738],
#  [12739, 12738, 12738],
#  [12739, 12738, 12738],
#  [12, 24, 32, 1419, 777, 12738, 12738],
#  [32, 150, 1989, 156, 1683, 12738, 12738],
#  [1559, 12738, 12738],
#  [1700, 1991, 12738, 12738],
#  [2009, 1048, 2010, 2011, 12738, 12738],
#  [48, 12738, 12738],
#  [1686, 12738, 12738],
#  [868, 508, 12738, 12738],
#  [529, 274, 386, 12738, 12738],
#  [868, 508, 12738, 12738],
#  [868, 508, 12738, 12738],
#  [12739, 1577, 1578, 12738, 12738],
#  [2013, 32, 825, 1243, 12738, 12738],
#  [1012, 158, 107, 12738, 12738],
#  [106, 1291, 12738, 12738],
#  [114, 2037, 101, 1119, 12738, 12738],
#  [84, 2048, 12738, 12738],
#  [43, 726, 2061, 12739, 12738, 12738],
#  [12, 168, 24, 2073, 57, 12738, 12738],
#  [646, 1369, 628, 12738, 12738],
#  [1246, 12738, 12738],
#  [2084, 129, 596, 2085, 12738, 12738],
#  [12739, 12738, 12738],
#  [1014, 129, 2103, 12738, 12738],
#  [43, 632, 2061, 12739, 12738, 12738],
#  [801, 12739, 186, 1161, 12738, 12738],
#  [14, 2116, 127, 12738, 12738],
#  [1246, 12738, 12738],
#  [12, 24, 2139, 12738, 12738],
#  [380, 125, 1001, 2164, 12738, 12738],
#  [1348, 1318, 426, 12738, 12738],
#  [111, 2168, 318, 12738, 12738],
#  [12, 90, 783, 2096, 890, 12738, 12738],
#  [825, 66, 1780, 2173, 12738, 12738],
#  [58, 12739, 2175, 12739, 12738, 12738],
#  [165, 101, 93, 2202, 12738, 12738],
#  [57, 12739, 12738, 12738],
#  [2066, 1845, 12739, 12738, 12738],
#  [12, 168, 24, 2073, 57, 12738, 12738],
#  [12739, 12, 964, 48, 12738, 12738],
#  [361, 1109, 12738, 12738],
#  [12, 156, 1020, 2243, 12738, 12738],
#  [1644, 12738, 12738],
#  [53, 14, 686, 12738, 12738],
#  [2228, 32, 48, 165, 12738, 12738],
#  [165, 101, 166, 316, 5, 236, 12738, 12738],
#  [165, 32, 361, 2276, 12739, 12738, 12738],
#  [32, 74, 12739, 12738, 12738],
#  [129, 2288, 12738, 12738],
#  [101, 852, 2291, 12738, 12738],
#  [848, 12, 32, 1125, 12738, 12738],
#  [106, 453, 5, 598, 12738, 12738],
#  [32, 370, 12739, 12738, 12738],
#  [32, 98, 572, 12738, 12738],
#  [12739, 62, 801, 505, 12738, 12738],
#  [644, 1320, 110, 12738, 12738],
#  [2262, 12738, 12738],
#  [12739, 17, 2052, 1872, 267, 12738, 12738],
#  [202, 688, 1626, 45, 600, 57, 12738, 12738],
#  [106, 42, 617, 469, 235, 12738, 12738],
#  [32, 2086, 57, 12738, 12738],
#  [1769, 1553, 12738, 12738],
#  [2362, 5, 43, 12738, 12738],
#  [1221, 12738, 12738],
#  [1221, 12738, 12738],
#  [1221, 12738, 12738],
#  [963, 1465, 12738, 12738],
#  [1815, 245, 12738, 12738],
#  [369, 1459, 12738, 12738],
#  [382, 2370, 12738, 12738],
#  [1012, 2394, 12738, 12738],
#  [1012, 106, 2394, 1815, 12738, 12738],
#  [1019, 33, 103, 1815, 646, 12738, 12738],
#  [1362, 1339, 245, 12738, 12738],
#  [2400, 12738, 12738],
#  [1339, 245, 12739, 12738, 12738],
#  [255, 110, 1301, 751, 12738, 12738],
#  [32, 1662, 1003, 2404, 12738, 12738],
#  [74, 1014, 12738, 12738],
#  [2409, 2410, 12738, 12738],
#  [57, 2411, 785, 1518, 12738, 12738],
#  [72, 165, 2415, 12739, 12738, 12738],
#  [537, 538, 110, 12738, 12738],
#  [12739, 2, 428, 2421, 12738, 12738],
#  [644, 12738, 12738],
#  [2422, 1, 2423, 12738, 12738],
#  [307, 1379, 169, 12739, 1241, 12738, 12738],
#  [165, 62, 282, 1014, 12738, 12738],
#  [513, 959, 12739, 12738, 12738],
#  [165, 921, 12738, 12738],
#  [165, 32, 1492, 12739, 12738, 12738],
#  [233, 62, 263, 617, 2439, 12738, 12738],
#  [42, 17, 572, 12738, 12738],
#  [2450, 45, 1053, 12739, 12738, 12738],
#  [1053, 12739, 12738, 12738],
#  [2436, 129, 2144, 12739, 12738, 12738],
#  [165, 12738, 12738],
#  [48, 1434, 36, 12738, 12738],
#  [165, 2, 68, 12738, 12738],
#  [57, 12, 12739, 12738, 12738],
#  [165, 12, 2465, 45, 114, 2, 48, 1827, 12738, 12738],
#  [2466, 2467, 2468, 283, 12738, 12738],
#  [876, 284, 12738, 12738],
#  [165, 101, 12738, 12738],
#  [2400, 165, 32, 2046, 12738, 12738],
#  [125, 1360, 12738, 12738],
#  [2454, 852, 12739, 12738, 12738],
#  [1189, 863, 12738, 12738],
#  [1113, 751, 283, 12738, 12738],
#  [12, 361, 2504, 12738, 12738],
#  [48, 12738, 12738],
#  [453, 12738, 12738],
#  [48, 17, 2523, 12738, 12738],
#  [832, 1301, 2533, 1927, 1792, 12738, 12738],
#  [233, 1113, 361, 67, 12738, 12738],
#  [12739, 407, 12738, 12738],
#  [48, 48, 48, 12738, 12738],
#  [1124, 2098, 2564, 1396, 12738, 12738],
#  [106, 325, 45, 2570, 12739, 12738, 12738],
#  [1362, 438, 12738, 12738],
#  [2581, 2581, 2581, 2582, 47, 12738, 12738],
#  [1012, 126, 12738, 12738],
#  [32, 762, 101, 12738, 12738],
#  [48, 48, 106, 151, 12739, 12738, 12738],
#  [2609, 2609, 12738, 12738],
#  [855, 1012, 106, 628, 12738, 12738],
#  [57, 12739, 12738, 12738],
#  [1132, 45, 414, 409, 45, 818, 414, 12738, 12738],
#  [32, 400, 1167, 45, 409, 12738, 12738],
#  [838, 12739, 12738, 12738],
#  [855, 57, 2584, 12738, 12738],
#  [101, 62, 101, 62, 12738, 12738],
#  [2242, 2242, 12738, 12738],
#  [2516, 2242, 12738, 12738],
#  [12, 98, 12738, 12738],
#  [101, 62, 12738, 12738],
#  [855, 1241, 12739, 62, 12738, 12738],
#  [255, 12738, 12738],
#  [12, 2624, 12738, 12738],
#  [12739, 12738, 12738],
#  [6, 2625, 44, 36, 2603, 12738, 12738],
#  [2242, 1038, 1003, 12738, 12738],
#  [412, 1242, 12739, 729, 2169, 12738, 12738],
#  [1124, 908, 12738, 12738],
#  [1362, 76, 12738, 12738],
#  [75, 2632, 520, 106, 282, 1227, 66, 12738, 12738],
#  [325, 150, 180, 2, 2241, 12738, 12738],
#  [2635, 186, 14, 12738, 12738],
#  [392, 2042, 12738, 12738],
#  [222, 1312, 222, 1056, 12738, 12738],
#  [1005, 2641, 826, 1130, 12738, 12738],
#  [233, 12738, 12738],
#  [98, 5, 726, 1194, 646, 12738, 12738],
#  [101, 68, 646, 751, 12738, 12738],
#  [233, 125, 1355, 1113, 90, 1093, 12738, 12738],
#  [1216, 952, 12738, 12738],
#  [372, 32, 67, 2650, 101, 283, 12738, 12738],
#  [2652, 419, 12738, 12738],
#  [62, 361, 107, 66, 12738, 12738],
#  [12, 515, 129, 12739, 12, 48, 90, 812, 12738, 12738],
#  [76, 28, 12738, 12738],
#  [2665, 2322, 2, 1189, 67, 12738, 12738],
#  [76, 28, 1362, 12, 57, 48, 255, 12738, 12738],
#  [255, 12738, 12738],
#  [2618, 176, 392, 101, 2, 726, 12738, 12738],
#  [818, 45, 367, 227, 1361, 2682, 12738, 12738],
#  [2454, 12738, 12738],
#  [12, 152, 12739, 66, 12739, 12738, 12738],
#  [1, 1355, 57, 2703, 12738, 12738],
#  [288, 1, 231, 1355, 386, 12738, 12738],
#  [2707, 804, 2708, 12738, 12738],
#  [939, 2715, 186, 910, 12739, 12738, 12738],
#  [2530, 32, 194, 186, 817, 12738, 12738],
#  [2730, 12739, 12738, 12738],
#  [393, 1962, 426, 12738, 12738],
#  [588, 12739, 45, 416, 12738, 12738],
#  [1537, 5, 729, 51, 12738, 12738],
#  [2737, 12, 45, 413, 414, 12738, 12738],
#  [185, 186, 929, 426, 12738, 12738],
#  [267, 215, 24, 2464, 12738, 12738],
#  [12, 1183, 12738, 12738],
#  [2737, 12738, 12738],
#  [2738, 2738, 2738, 12738, 12738],
#  [48, 48, 12738, 12738],
#  [1887, 426, 12738, 12738],
#  [1337, 1337, 12738, 12738],
#  [380, 380, 12, 12738, 12738],
#  [2498, 12738, 12738],
#  [2498, 12738, 12738],
#  [76, 28, 12738, 12738],
#  [2525, 12739, 165, 2, 68, 12738, 12738],
#  [2765, 1626, 563, 12738, 12738],
#  [2785, 1149, 12738, 12738],
#  [165, 205, 2657, 12738, 12738],
#  [57, 318, 12739, 12738, 12738],
#  [380, 267, 1189, 2642, 12738, 12738],
#  [1467, 1398, 12738, 12738],
#  [1123, 45, 929, 1398, 267, 1014, 12738, 12738],
#  [125, 194, 186, 414, 12738, 12738],
#  [372, 2805, 47, 2242, 12738, 12738],
#  [2796, 12, 24, 32, 2807, 12738, 12738],
#  [2809, 12738, 12738],
#  [12, 48, 368, 12738, 12738],
#  [818, 5, 318, 66, 12738, 12738],
#  [646, 48, 2813, 12, 1419, 12738, 12738],
#  [307, 1, 90, 103, 448, 2254, 106, 12738, 12738],
#  [12, 48, 67, 165, 2, 68, 12738, 12738],
#  [2737, 380, 12, 12738, 12738],
#  [419, 32, 48, 90, 2831, 2100, 57, 12738, 12738],
#  [90, 629, 2100, 419, 12738, 12738],
#  [2290, 2839, 12738, 12738],
#  [186, 1784, 2842, 12738, 12738],
#  [12, 67, 1984, 62, 1077, 12738, 12738],
#  [2, 2536, 109, 12738, 12738],
#  [372, 74, 1927, 1792, 1051, 12738, 12738],
#  [2851, 1110, 2852, 12738, 12738],
#  [281, 57, 2, 63, 1113, 2620, 12738, 12738],
#  [2851, 186, 1569, 150, 2567, 12738, 12738],
#  [537, 538, 12738, 12738],
#  [372, 372, 12738, 12738],
#  [889, 915, 36, 915, 12738, 12738],
#  [1362, 438, 112, 12739, 12738, 12738],
#  [2820, 12738, 12738],
#  [98, 12738, 12738],
#  [537, 538, 12738, 12738],
#  [168, 1206, 651, 496, 12738, 12738],
#  [386, 231, 2100, 611, 12738, 12738],
#  [628, 103, 2493, 563, 57, 12738, 12738],
#  [1962, 868, 708, 852, 62, 12738, 12738],
#  [233, 12, 282, 1216, 2, 829, 12738, 12738],
#  [32, 2677, 12739, 2911, 12738, 12738],
#  [62, 562, 437, 32, 67, 12738, 12738],
#  [2510, 2844, 12738, 12738],
#  [2454, 373, 57, 2737, 2741, 12738, 12738],
#  [1, 57, 217, 1322, 12738, 12738],
#  [62, 12738, 12738],
#  [12, 355, 73, 62, 1437, 12738, 12738],
#  [1362, 1913, 1124, 62, 2948, 12738, 12738],
#  [165, 205, 2657, 12738, 12738],
#  [12739, 2173, 12738, 12738],
#  [2973, 771, 692, 12738, 12738],
#  [762, 12, 1, 692, 12738, 12738],
#  [186, 14, 298, 2076, 12739, 12738, 12738],
#  [2287, 651, 952, 12738, 12738],
#  [233, 2, 354, 2077, 12738, 12738],
#  [165, 12738, 12738],
#  [165, 12738, 12738],
#  [2640, 12738, 12738],
#  [12, 469, 2098, 12738, 12738],
#  [12, 469, 2098, 12738, 12738],
#  [561, 12738, 12738],
#  [372, 2995, 12738, 12738],
#  [12, 970, 45, 3000, 12738, 12738],
#  [165, 205, 2657, 12738, 12738],
#  [101, 587, 536, 12738, 12738],
#  [1902, 1113, 1337, 5, 929, 12738, 12738],
#  [255, 3004, 12738, 12738],
#  [62, 1366, 2646, 2584, 12738, 12738],
#  [959, 101, 45, 910, 12739, 12738, 12738],
#  [3021, 2491, 12739, 12738, 12738],
#  [2820, 12738, 12738],
#  [2914, 62, 12738, 12738],
#  [1241, 12, 282, 330, 12738, 12738],
#  [561, 12738, 12738],
#  [372, 2516, 57, 2567, 57, 2737, 2741, 12738, 12738],
#  [2267, 45, 88, 3030, 12738, 12738],
#  [255, 12738, 12738],
#  [1362, 1194, 393, 12738, 12738],
#  [76, 28, 12738, 12738],
#  [1189, 630, 62, 12739, 12738, 12738],
#  [2189, 1514, 2, 62, 74, 12738, 12738],
#  [1194, 32, 253, 428, 12738, 12738],
#  [2242, 12738, 12738],
#  [76, 12738, 12738],
#  [2399, 12738, 12738],
#  [2581, 12738, 12738],
#  [267, 12738, 12738],
#  [76, 12738, 12738],
#  [2581, 12738, 12738],
#  [3053, 12738, 12738],
#  [3043, 12738, 12738],
#  [165, 205, 2657, 12738, 12738],
#  [2879, 3060, 2912, 45, 12739, 3057, 12738, 12738],
#  [380, 12738, 12738],
#  [373, 1398, 372, 372, 1398, 267, 12738, 12738],
#  [1124, 3066, 1002, 36, 12738, 12738],
#  [110, 125, 3067, 2744, 12738, 12738],
#  [83, 12738, 12738],
#  [2524, 2242, 1012, 107, 426, 12738, 12738],
#  [3065, 916, 267, 12738, 12738],
#  [150, 12738, 12738],
#  [12, 630, 1194, 361, 124, 12738, 12738],
#  [165, 205, 2657, 12738, 12738],
#  [649, 62, 12738, 12738],
#  [3039, 12738, 12738],
#  [2498, 2498, 12738, 12738],
#  [855, 431, 3074, 12738, 12738],
#  [2498, 45, 409, 1051, 12738, 12738],
#  [1362, 28, 57, 2090, 12738, 12738],
#  [1241, 12738, 12738],
#  [62, 940, 12738, 12738],
#  ...]

# %% [markdown]
# ### Litte check

# %%
def konv_ques(slist):
    rslt = ""
    for i in slist:
        rslt = rslt + questionint2word[i] + " "
    return print(rslt)

# %%
def konv_ans(slist):
    rslt = ""
    for i in slist:
        rslt = rslt + answerint2word[i] + " "
    return print(rslt)

# %%
konv_ques(alf)
# Out:
# woojin nama unit yang aku pikirkan adalah just dance karena aku membayangkan menari bersama wannable dengan lagu yang aku suka menarilah just dance <EOS>

# %%
import pickle
pickle.dump(sort_question_n,open('sort_question_n.pickle','wb'))
sorted_que = pickle.load(open('sort_question_n.pickle','rb'))

pickle.dump(sort_answer_n,open('sort_answer_n.pickle','wb'))
sorted_ans = pickle.load(open('sort_answer_n.pickle','rb'))

# %%
sorted_que
# Out:
# [[10032, 10031],
#  [74, 10031],
#  [68, 10031],
#  [82, 10031],
#  [83, 10031],
#  [78, 10031],
#  [158, 10031],
#  [78, 10031],
#  [38, 10031],
#  [185, 10031],
#  [198, 10031],
#  [206, 10031],
#  [219, 10031],
#  [232, 10031],
#  [247, 10031],
#  [185, 10031],
#  [253, 10031],
#  [46, 10031],
#  [185, 10031],
#  [74, 10031],
#  [356, 10031],
#  [46, 10031],
#  [360, 10031],
#  [251, 10031],
#  [359, 10031],
#  [78, 10031],
#  [368, 10031],
#  [122, 10031],
#  [389, 10031],
#  [402, 10031],
#  [423, 10031],
#  [125, 10031],
#  [122, 10031],
#  [427, 10031],
#  [476, 10031],
#  [487, 10031],
#  [38, 10031],
#  [386, 10031],
#  [74, 10031],
#  [538, 10031],
#  [554, 10031],
#  [386, 10031],
#  [298, 10031],
#  [74, 10031],
#  [74, 10031],
#  [74, 10031],
#  [74, 10031],
#  [610, 10031],
#  [615, 10031],
#  [413, 10031],
#  [251, 10031],
#  [61, 10031],
#  [361, 10031],
#  [361, 10031],
#  [10032, 10031],
#  [677, 10031],
#  [175, 10031],
#  [46, 10031],
#  [107, 10031],
#  [260, 10031],
#  [710, 10031],
#  [74, 10031],
#  [742, 10031],
#  [432, 10031],
#  [49, 10031],
#  [10032, 10031],
#  [805, 10031],
#  [412, 10031],
#  [159, 10031],
#  [46, 10031],
#  [124, 10031],
#  [316, 10031],
#  [822, 10031],
#  [185, 10031],
#  [251, 10031],
#  [251, 10031],
#  [251, 10031],
#  [251, 10031],
#  [357, 10031],
#  [782, 10031],
#  [423, 10031],
#  [873, 10031],
#  [172, 10031],
#  [169, 10031],
#  [89, 10031],
#  [258, 10031],
#  [169, 10031],
#  [10032, 10031],
#  [185, 10031],
#  [169, 10031],
#  [793, 10031],
#  [46, 10031],
#  [46, 10031],
#  [793, 10031],
#  [74, 10031],
#  [602, 10031],
#  [10032, 10031],
#  [10032, 10031],
#  [74, 10031],
#  [68, 10031],
#  [82, 10031],
#  [83, 10031],
#  [78, 10031],
#  [158, 10031],
#  [78, 10031],
#  [38, 10031],
#  [185, 10031],
#  [198, 10031],
#  [206, 10031],
#  [219, 10031],
#  [232, 10031],
#  [247, 10031],
#  [185, 10031],
#  [253, 10031],
#  [46, 10031],
#  [185, 10031],
#  [74, 10031],
#  [356, 10031],
#  [46, 10031],
#  [360, 10031],
#  [251, 10031],
#  [359, 10031],
#  [78, 10031],
#  [368, 10031],
#  [122, 10031],
#  [389, 10031],
#  [402, 10031],
#  [423, 10031],
#  [125, 10031],
#  [122, 10031],
#  [427, 10031],
#  [476, 10031],
#  [487, 10031],
#  [38, 10031],
#  [386, 10031],
#  [74, 10031],
#  [538, 10031],
#  [554, 10031],
#  [386, 10031],
#  [298, 10031],
#  [74, 10031],
#  [74, 10031],
#  [74, 10031],
#  [74, 10031],
#  [610, 10031],
#  [615, 10031],
#  [413, 10031],
#  [251, 10031],
#  [61, 10031],
#  [361, 10031],
#  [361, 10031],
#  [10032, 10031],
#  [677, 10031],
#  [175, 10031],
#  [46, 10031],
#  [107, 10031],
#  [260, 10031],
#  [710, 10031],
#  [74, 10031],
#  [742, 10031],
#  [432, 10031],
#  [49, 10031],
#  [10032, 10031],
#  [805, 10031],
#  [412, 10031],
#  [159, 10031],
#  [46, 10031],
#  [124, 10031],
#  [316, 10031],
#  [822, 10031],
#  [185, 10031],
#  [251, 10031],
#  [251, 10031],
#  [251, 10031],
#  [251, 10031],
#  [357, 10031],
#  [782, 10031],
#  [423, 10031],
#  [873, 10031],
#  [172, 10031],
#  [169, 10031],
#  [89, 10031],
#  [258, 10031],
#  [169, 10031],
#  [10032, 10031],
#  [185, 10031],
#  [169, 10031],
#  [793, 10031],
#  [46, 10031],
#  [46, 10031],
#  [793, 10031],
#  [74, 10031],
#  [602, 10031],
#  [10032, 10031],
#  [957, 10031],
#  [167, 10031],
#  [951, 10031],
#  [103, 10031],
#  [879, 10031],
#  [1001, 10031],
#  [610, 10031],
#  [1022, 10031],
#  [369, 10031],
#  [46, 10031],
#  [74, 10031],
#  [1078, 10031],
#  [247, 10031],
#  [1063, 10031],
#  [225, 10031],
#  [1134, 10031],
#  [247, 10031],
#  [1150, 10031],
#  [10032, 10031],
#  [10032, 10031],
#  [1164, 10031],
#  [1179, 10031],
#  [360, 10031],
#  [10032, 10031],
#  [1018, 10031],
#  [10032, 10031],
#  [1183, 10031],
#  [605, 10031],
#  [1108, 10031],
#  [1108, 10031],
#  [360, 10031],
#  [159, 10031],
#  [1134, 10031],
#  [1029, 10031],
#  [74, 10031],
#  [10032, 10031],
#  [918, 10031],
#  [360, 10031],
#  [360, 10031],
#  [10032, 10031],
#  [159, 10031],
#  [1261, 10031],
#  [780, 10031],
#  [10032, 10031],
#  [360, 10031],
#  [360, 10031],
#  [360, 10031],
#  [10032, 10031],
#  [1274, 10031],
#  [1281, 10031],
#  [1286, 10031],
#  [610, 10031],
#  [1075, 10031],
#  [25, 10031],
#  [502, 10031],
#  [247, 10031],
#  [959, 10031],
#  [1262, 10031],
#  [185, 10031],
#  [1314, 10031],
#  [1314, 10031],
#  [1314, 10031],
#  [360, 10031],
#  [74, 10031],
#  [1316, 10031],
#  [225, 10031],
#  [369, 10031],
#  [780, 10031],
#  [10032, 10031],
#  [968, 10031],
#  [1240, 10031],
#  [10032, 10031],
#  [1240, 10031],
#  [1103, 10031],
#  [360, 10031],
#  [247, 10031],
#  [1038, 10031],
#  [46, 10031],
#  [374, 10031],
#  [10032, 10031],
#  [1107, 10031],
#  [1084, 10031],
#  [1084, 10031],
#  [74, 10031],
#  [1108, 10031],
#  [621, 10031],
#  [1274, 10031],
#  [1029, 10031],
#  [10032, 10031],
#  [85, 10031],
#  [879, 10031],
#  [1063, 10031],
#  [159, 10031],
#  [1134, 10031],
#  [1072, 10031],
#  [145, 10031],
#  [10032, 10031],
#  [1385, 10031],
#  [1063, 10031],
#  [10032, 10031],
#  [110, 10031],
#  [159, 10031],
#  [30, 10031],
#  [1402, 10031],
#  [104, 10031],
#  [1404, 10031],
#  [369, 10031],
#  [910, 10031],
#  [360, 10031],
#  [1010, 10031],
#  [423, 10031],
#  [10032, 10031],
#  [159, 10031],
#  [10032, 10031],
#  [55, 10031],
#  [104, 10031],
#  [1424, 10031],
#  [689, 10031],
#  [225, 10031],
#  [360, 10031],
#  [247, 10031],
#  [1070, 10031],
#  [247, 10031],
#  [203, 10031],
#  [369, 10031],
#  [159, 10031],
#  [1072, 10031],
#  [126, 10031],
#  [309, 10031],
#  [123, 10031],
#  [104, 10031],
#  [1464, 10031],
#  [107, 10031],
#  [1474, 10031],
#  [1263, 10031],
#  [968, 10031],
#  [1477, 10031],
#  [941, 10031],
#  [742, 10031],
#  [107, 10031],
#  [1487, 10031],
#  [822, 10031],
#  [10032, 10031],
#  [10032, 10031],
#  [1526, 10031],
#  [10032, 10031],
#  [1527, 10031],
#  [10032, 10031],
#  [10032, 10031],
#  [10032, 10031],
#  [10032, 10031],
#  [10032, 10031],
#  [10032, 10031],
#  [206, 10031],
#  [1535, 10031],
#  [10032, 10031],
#  [1400, 10031],
#  [10032, 10031],
#  [10032, 10031],
#  [369, 10031],
#  [1483, 10031],
#  [1518, 10031],
#  [1483, 10031],
#  [610, 10031],
#  [74, 10031],
#  [974, 10031],
#  [974, 10031],
#  [968, 10031],
#  [206, 10031],
#  [1605, 10031],
#  [822, 10031],
#  [968, 10031],
#  [206, 10031],
#  [30, 10031],
#  [1483, 10031],
#  [1518, 10031],
#  [333, 10031],
#  [1646, 10031],
#  [10032, 10031],
#  [107, 10031],
#  [1650, 10031],
#  [1483, 10031],
#  [822, 10031],
#  [10032, 10031],
#  [74, 10031],
#  [1493, 10031],
#  [1486, 10031],
#  [159, 10031],
#  [1486, 10031],
#  [1682, 10031],
#  [46, 10031],
#  [61, 10031],
#  [822, 10031],
#  [1493, 10031],
#  [107, 10031],
#  [1372, 10031],
#  [603, 10031],
#  [968, 10031],
#  [968, 10031],
#  [107, 10031],
#  [83, 10031],
#  [83, 10031],
#  [1726, 10031],
#  [104, 10031],
#  [83, 10031],
#  [1605, 10031],
#  [1729, 10031],
#  [1605, 10031],
#  [1605, 10031],
#  [968, 10031],
#  [968, 10031],
#  [1605, 10031],
#  [968, 10031],
#  [107, 10031],
#  [46, 10031],
#  [1353, 10031],
#  [360, 10031],
#  [46, 10031],
#  [822, 10031],
#  [1646, 10031],
#  [793, 10031],
#  [1488, 10031],
#  [1493, 10031],
#  [374, 10031],
#  [10032, 10031],
#  [1498, 10031],
#  [1498, 10031],
#  [834, 10031],
#  [822, 10031],
#  [1787, 10031],
#  [1649, 10031],
#  [1568, 10031],
#  [1568, 10031],
#  [107, 10031],
#  [185, 10031],
#  [1790, 10031],
#  [1474, 10031],
#  [1474, 10031],
#  [1791, 10031],
#  [1493, 10031],
#  [198, 10031],
#  [55, 10031],
#  [46, 10031],
#  [1518, 10031],
#  [61, 10031],
#  [968, 10031],
#  [1860, 10031],
#  [1483, 10031],
#  [107, 10031],
#  [1488, 10031],
#  [1861, 10031],
#  [1568, 10031],
#  [10032, 10031],
#  [732, 10031],
#  [159, 10031],
#  [1483, 10031],
#  [360, 10031],
#  [1681, 10031],
#  [1681, 10031],
#  [10032, 10031],
#  [206, 10031],
#  [10032, 10031],
#  [10032, 10031],
#  [46, 10031],
#  [1646, 10031],
#  [1493, 10031],
#  [1493, 10031],
#  [1646, 10031],
#  [46, 10031],
#  [1605, 10031],
#  [1582, 10031],
#  [1336, 10031],
#  [1218, 10031],
#  [10032, 10031],
#  [360, 10031],
#  [610, 10031],
#  [1488, 10031],
#  [10032, 10031],
#  [74, 10031],
#  [68, 10031],
#  [82, 10031],
#  [83, 10031],
#  [78, 10031],
#  [158, 10031],
#  [78, 10031],
#  [38, 10031],
#  [185, 10031],
#  [198, 10031],
#  [206, 10031],
#  [219, 10031],
#  [232, 10031],
#  [247, 10031],
#  [185, 10031],
#  [253, 10031],
#  [46, 10031],
#  [185, 10031],
#  [74, 10031],
#  [356, 10031],
#  [46, 10031],
#  [360, 10031],
#  [251, 10031],
#  [359, 10031],
#  [78, 10031],
#  [368, 10031],
#  [122, 10031],
#  [389, 10031],
#  [402, 10031],
#  [423, 10031],
#  [125, 10031],
#  [122, 10031],
#  [427, 10031],
#  [476, 10031],
#  [487, 10031],
#  [38, 10031],
#  [386, 10031],
#  [74, 10031],
#  [538, 10031],
#  [554, 10031],
#  [386, 10031],
#  [298, 10031],
#  [74, 10031],
#  [74, 10031],
#  [74, 10031],
#  [74, 10031],
#  [610, 10031],
#  [615, 10031],
#  [413, 10031],
#  [251, 10031],
#  [61, 10031],
#  [361, 10031],
#  [361, 10031],
#  [10032, 10031],
#  [677, 10031],
#  [175, 10031],
#  [46, 10031],
#  [107, 10031],
#  [260, 10031],
#  [710, 10031],
#  [74, 10031],
#  [742, 10031],
#  [432, 10031],
#  [49, 10031],
#  [10032, 10031],
#  [805, 10031],
#  [412, 10031],
#  [159, 10031],
#  [46, 10031],
#  [124, 10031],
#  [316, 10031],
#  [822, 10031],
#  [185, 10031],
#  [251, 10031],
#  [251, 10031],
#  [251, 10031],
#  [251, 10031],
#  [357, 10031],
#  [782, 10031],
#  [423, 10031],
#  [873, 10031],
#  [172, 10031],
#  [169, 10031],
#  [89, 10031],
#  [258, 10031],
#  [169, 10031],
#  [10032, 10031],
#  [185, 10031],
#  [169, 10031],
#  [793, 10031],
#  [46, 10031],
#  [46, 10031],
#  [793, 10031],
#  [74, 10031],
#  [602, 10031],
#  [10032, 10031],
#  [1464, 10031],
#  [107, 10031],
#  [1474, 10031],
#  [1263, 10031],
#  [968, 10031],
#  [1477, 10031],
#  [941, 10031],
#  [742, 10031],
#  [107, 10031],
#  [1487, 10031],
#  [822, 10031],
#  [10032, 10031],
#  [10032, 10031],
#  [1526, 10031],
#  [10032, 10031],
#  [1527, 10031],
#  [10032, 10031],
#  [10032, 10031],
#  [10032, 10031],
#  [10032, 10031],
#  [10032, 10031],
#  [10032, 10031],
#  [206, 10031],
#  [1535, 10031],
#  [10032, 10031],
#  [1400, 10031],
#  [10032, 10031],
#  [10032, 10031],
#  [369, 10031],
#  [1483, 10031],
#  [1518, 10031],
#  [1483, 10031],
#  [610, 10031],
#  [74, 10031],
#  [974, 10031],
#  [974, 10031],
#  [968, 10031],
#  [206, 10031],
#  [1605, 10031],
#  [822, 10031],
#  [968, 10031],
#  [206, 10031],
#  [30, 10031],
#  [1483, 10031],
#  [1518, 10031],
#  [333, 10031],
#  [1646, 10031],
#  [10032, 10031],
#  [107, 10031],
#  [1650, 10031],
#  [1483, 10031],
#  [822, 10031],
#  [10032, 10031],
#  [74, 10031],
#  [1493, 10031],
#  [1486, 10031],
#  [159, 10031],
#  [1486, 10031],
#  [1682, 10031],
#  [46, 10031],
#  [61, 10031],
#  [822, 10031],
#  [1493, 10031],
#  [107, 10031],
#  [1372, 10031],
#  [603, 10031],
#  [968, 10031],
#  [968, 10031],
#  [107, 10031],
#  [83, 10031],
#  [83, 10031],
#  [1726, 10031],
#  [104, 10031],
#  [83, 10031],
#  [1605, 10031],
#  [1729, 10031],
#  [1605, 10031],
#  [1605, 10031],
#  [968, 10031],
#  [968, 10031],
#  [1605, 10031],
#  [968, 10031],
#  [107, 10031],
#  [46, 10031],
#  [1353, 10031],
#  [360, 10031],
#  [46, 10031],
#  [822, 10031],
#  [1646, 10031],
#  [793, 10031],
#  [1488, 10031],
#  [1493, 10031],
#  [374, 10031],
#  [10032, 10031],
#  [1498, 10031],
#  [1498, 10031],
#  [834, 10031],
#  [822, 10031],
#  [1787, 10031],
#  [1649, 10031],
#  [1568, 10031],
#  [1568, 10031],
#  [107, 10031],
#  [185, 10031],
#  [1790, 10031],
#  [1474, 10031],
#  [1474, 10031],
#  [1791, 10031],
#  [1493, 10031],
#  [198, 10031],
#  [55, 10031],
#  [46, 10031],
#  [1518, 10031],
#  [61, 10031],
#  [968, 10031],
#  [1860, 10031],
#  [1483, 10031],
#  [107, 10031],
#  [1488, 10031],
#  [1861, 10031],
#  [1568, 10031],
#  [10032, 10031],
#  [732, 10031],
#  [159, 10031],
#  [1483, 10031],
#  [360, 10031],
#  [1681, 10031],
#  [1681, 10031],
#  [10032, 10031],
#  [206, 10031],
#  [10032, 10031],
#  [10032, 10031],
#  [46, 10031],
#  [1646, 10031],
#  [1493, 10031],
#  [1493, 10031],
#  [1646, 10031],
#  [46, 10031],
#  [1605, 10031],
#  [1582, 10031],
#  [1336, 10031],
#  [1218, 10031],
#  [10032, 10031],
#  [360, 10031],
#  [610, 10031],
#  [1488, 10031],
#  [10032, 10031],
#  [225, 10031],
#  [822, 10031],
#  [172, 10031],
#  [747, 10031],
#  [1188, 10031],
#  [1188, 10031],
#  [822, 10031],
#  [10032, 10031],
#  [10032, 10031],
#  [103, 10031],
#  [721, 10031],
#  [822, 10031],
#  [1188, 10031],
#  [173, 10031],
#  [10032, 10031],
#  [1188, 10031],
#  [2043, 10031],
#  [1225, 10031],
#  [56, 10031],
#  [1261, 10031],
#  [822, 10031],
#  [10032, 10031],
#  [822, 10031],
#  [2094, 10031],
#  [2106, 10031],
#  [357, 10031],
#  [209, 10031],
#  [1568, 10031],
#  [10032, 10031],
#  [10032, 10031],
#  [1962, 10031],
#  [71, 10031],
#  [822, 10031],
#  [1225, 10031],
#  [2152, 10031],
#  [822, 10031],
#  [1877, 10031],
#  [10032, 10031],
#  [46, 10031],
#  [822, 10031],
#  [2125, 10031],
#  [2125, 10031],
#  [10032, 10031],
#  [1631, 10031],
#  [10032, 10031],
#  [1681, 10031],
#  [10032, 10031],
#  [1164, 10031],
#  [1164, 10031],
#  [1164, 10031],
#  [1164, 10031],
#  [1164, 10031],
#  [1225, 10031],
#  [2221, 10031],
#  [274, 10031],
#  [10032, 10031],
#  [159, 10031],
#  [2249, 10031],
#  [237, 10031],
#  [2250, 10031],
#  [2252, 10031],
#  [61, 10031],
#  [33, 10031],
#  [822, 10031],
#  [369, 10031],
#  [2263, 10031],
#  [2267, 10031],
#  [309, 10031],
#  [10032, 10031],
#  [621, 10031],
#  [539, 10031],
#  [10032, 10031],
#  [2249, 10031],
#  [146, 10031],
#  [2106, 10031],
#  [1225, 10031],
#  [82, 10031],
#  [423, 10031],
#  [74, 10031],
#  [1164, 10031],
#  [1035, 10031],
#  [159, 10031],
#  [159, 10031],
#  [621, 10031],
#  [10032, 10031],
#  [539, 10031],
#  [159, 10031],
#  [73, 10031],
#  [159, 10031],
#  [576, 10031],
#  [539, 10031],
#  [10032, 10031],
#  [46, 10031],
#  [1096, 10031],
#  [46, 10031],
#  [46, 10031],
#  [437, 10031],
#  [247, 10031],
#  [2385, 10031],
#  [10032, 10031],
#  [10032, 10031],
#  [46, 10031],
#  [423, 10031],
#  [1322, 10031],
#  [360, 10031],
#  [46, 10031],
#  [2429, 10031],
#  [822, 10031],
#  [2443, 10031],
#  [822, 10031],
#  [975, 10031],
#  [2449, 10031],
#  [699, 10031],
#  [822, 10031],
#  [74, 10031],
#  [2106, 10031],
#  [2106, 10031],
#  [74, 10031],
#  [2106, 10031],
#  [274, 10031],
#  [74, 10031],
#  [2106, 10031],
#  [247, 10031],
#  [46, 10031],
#  [10032, 10031],
#  [10032, 10031],
#  [10032, 10031],
#  [999, 10031],
#  [247, 10031],
#  [822, 10031],
#  [360, 10031],
#  [159, 10031],
#  [1005, 10031],
#  [2472, 10031],
#  [2472, 10031],
#  [1225, 10031],
#  [225, 10031],
#  [46, 10031],
#  [2373, 10031],
#  [247, 10031],
#  [2301, 10031],
#  [2483, 10031],
#  [1301, 10031],
#  [708, 10031],
#  [2452, 10031],
#  [206, 10031],
#  [206, 10031],
#  [2356, 10031],
#  [247, 10031],
#  [1183, 10031],
#  [1096, 10031],
#  [2302, 10031],
#  [74, 10031],
#  [2249, 10031],
#  [2535, 10031],
#  [10032, 10031],
#  [46, 10031],
#  [2557, 10031],
#  [88, 10031],
#  [247, 10031],
#  [1103, 10031],
#  [2535, 10031],
#  [74, 10031],
#  [2106, 10031],
#  [2564, 10031],
#  [395, 10031],
#  [2563, 10031],
#  [159, 10031],
#  [1787, 10031],
#  [2564, 10031],
#  [369, 10031],
#  [2573, 10031],
#  [2340, 10031],
#  [2340, 10031],
#  [51, 10031],
#  [46, 10031],
#  [423, 10031],
#  [2610, 10031],
#  [74, 10031],
#  [247, 10031],
#  [2617, 10031],
#  [2620, 10031],
#  [360, 10031],
#  [822, 10031],
#  [2617, 10031],
#  [1301, 10031],
#  [10032, 10031],
#  [46, 10031],
#  [360, 10031],
#  [2639, 10031],
#  [2356, 10031],
#  [368, 10031],
#  [178, 10031],
#  [247, 10031],
#  [247, 10031],
#  [247, 10031],
#  [406, 10031],
#  [1301, 10031],
#  [2667, 10031],
#  [46, 10031],
#  [2639, 10031],
#  [247, 10031],
#  [74, 10031],
#  [104, 10031],
#  [10032, 10031],
#  [203, 10031],
#  [247, 10031],
#  [2639, 10031],
#  [95, 10031],
#  [247, 10031],
#  [2700, 10031],
#  [2483, 10031],
#  [1301, 10031],
#  [2483, 10031],
#  [2639, 10031],
#  [145, 10031],
#  [2385, 10031],
#  [74, 10031],
#  [74, 10031],
#  [173, 10031],
#  [60, 10031],
#  [2759, 10031],
#  [203, 10031],
#  [732, 10031],
#  [1103, 10031],
#  [2792, 10031],
#  [732, 10031],
#  [247, 10031],
#  [610, 10031],
#  [2352, 10031],
#  [159, 10031],
#  [159, 10031],
#  [2472, 10031],
#  [2448, 10031],
#  [413, 10031],
#  [539, 10031],
#  [10032, 10031],
#  [1681, 10031],
#  [400, 10031],
#  [2815, 10031],
#  [1183, 10031],
#  [413, 10031],
#  [173, 10031],
#  [2385, 10031],
#  [1301, 10031],
#  [2639, 10031],
#  [2639, 10031],
#  [46, 10031],
#  [539, 10031],
#  [74, 10031],
#  [274, 10031],
#  [247, 10031],
#  [360, 10031],
#  [2270, 10031],
#  [2851, 10031],
#  [2860, 10031],
#  [1096, 10031],
#  [2106, 10031],
#  [74, 10031],
#  [2249, 10031],
#  [2416, 10031],
#  [259, 10031],
#  [74, 10031],
#  [2416, 10031],
#  [2861, 10031],
#  [2851, 10031],
#  [368, 10031],
#  [81, 10031],
#  [368, 10031],
#  [81, 10031],
#  [107, 10031],
#  [2861, 10031],
#  [81, 10031],
#  [822, 10031],
#  [1138, 10031],
#  [145, 10031],
#  [10032, 10031],
#  [2878, 10031],
#  [1402, 10031],
#  [2847, 10031],
#  [2249, 10031],
#  [1301, 10031],
#  [1096, 10031],
#  [1183, 10031],
#  [1183, 10031],
#  ...]

# %%
for idx, i in enumerate(sorted_que):
    lnn = len(i)
    if lnn < 25:
        for ii in range(25-lnn):
            sorted_que[idx].append(questionswords2int['<PAD>'])

# %%
for idx, i in enumerate(sorted_ans):
    lnn = len(i)
    if lnn < 25:
        for ii in range(25-lnn):
            sorted_ans[idx].append(answerswords2int['<PAD>'])

# %%
konv_ans(sorted_ans[0])
# Out:
# bakar <OUT> <OUT> <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>

# %%
pickle.dump(sorted_que,open('sorted_que.pickle','wb'))
pickle.dump(sorted_que,open('sorted_ans.pickle','wb'))
